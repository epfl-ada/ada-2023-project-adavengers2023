# %% [markdown]
# #### This is to experiment/clean the cluster dataset. I will later merge this to the main (Milestone2) notebook

# %%
import pandas as pd
import numpy as np

# %%
df_1=pd.read_table('data/tvtropes.clusters.txt',header=None)
df_1
# Out:
#                            0  \
# 0    absent_minded_professor
# 1    absent_minded_professor
# 2    absent_minded_professor
# 3    absent_minded_professor
# 4    absent_minded_professor
# ..                       ...
# 496                young_gun
# 497                young_gun
# 498                young_gun
# 499                young_gun
# 500                young_gun
#
#                                                      1
# 0    {"char": "Professor Philip Brainard", "movie":...
# 1    {"char": "Professor Keenbean", "movie": "Richi...
# 2    {"char": "Dr. Reinhardt Lane", "movie": "The S...
# 3    {"char": "Dr. Harold Medford", "movie": "Them!...
# 4    {"char": "Daniel Jackson", "movie": "Stargate"...
# ..                                                 ...
# 496  {"char": "Morgan Earp", "movie": "Tombstone", ...
# 497  {"char": "Colorado Ryan", "movie": "Rio Bravo"...
# 498  {"char": "Tom Sawyer", "movie": "The League of...
# ...

# %%
df_1.columns
# Out:
# Index([0, 1], dtype='int64')

# %%
df_1.loc[:,[1]]
# Out:
#                                                      1
# 0    {"char": "Professor Philip Brainard", "movie":...
# 1    {"char": "Professor Keenbean", "movie": "Richi...
# 2    {"char": "Dr. Reinhardt Lane", "movie": "The S...
# 3    {"char": "Dr. Harold Medford", "movie": "Them!...
# 4    {"char": "Daniel Jackson", "movie": "Stargate"...
# ..                                                 ...
# 496  {"char": "Morgan Earp", "movie": "Tombstone", ...
# 497  {"char": "Colorado Ryan", "movie": "Rio Bravo"...
# 498  {"char": "Tom Sawyer", "movie": "The League of...
# 499  {"char": "William H. 'Billy the Kid' Bonney", ...
# 500  {"char": "Jake", "movie": "Silverado", "id": "...
#
# [501 rows x 1 columns]

# %%
df_test = pd.json_normalize(df_1.loc[:,[1]])

# %%
df_test
# Out:
# Empty DataFrame
# Columns: []
# Index: [0]

# %%
df_expanded = pd.json_normalize(df['dict_column'])

# %%
print(df[1][1])
# Out:
# {"char": "Professor Keenbean", "movie": "Richie Rich", "id": "/m/02vchl3", "actor": "Michael McShane"}

# %%
data = {'dict_column': [{"char": "Professor Keenbean", "movie": "Richie Rich", "id": "/m/02vchl3", "actor": "Michael McShane"}]}
df = pd.DataFrame(data)
df
# Out:
#                                          dict_column
# 0  {'char': 'Professor Keenbean', 'movie': 'Richi...

# %%
df_expanded = pd.json_normalize(df['dict_column'])
df_expanded
# Out:
#                  char        movie          id            actor
# 0  Professor Keenbean  Richie Rich  /m/02vchl3  Michael McShane

# %%
df_final = pd.concat([df_1, df_expanded], axis=1)
df_final
# Out:
#                            0  \
# 0    absent_minded_professor
# 1    absent_minded_professor
# 2    absent_minded_professor
# 3    absent_minded_professor
# 4    absent_minded_professor
# ..                       ...
# 496                young_gun
# 497                young_gun
# 498                young_gun
# 499                young_gun
# 500                young_gun
#
#                                                      1                char  \
# 0    {"char": "Professor Philip Brainard", "movie":...  Professor Keenbean
# 1    {"char": "Professor Keenbean", "movie": "Richi...                 NaN
# 2    {"char": "Dr. Reinhardt Lane", "movie": "The S...                 NaN
# 3    {"char": "Dr. Harold Medford", "movie": "Them!...                 NaN
# 4    {"char": "Daniel Jackson", "movie": "Stargate"...                 NaN
# ..                                                 ...                 ...
# 496  {"char": "Morgan Earp", "movie": "Tombstone", ...                 NaN
# ...

# %%
a = df_final.drop(1,axis=1)

# %%
a
# Out:
#                            0                char        movie          id  \
# 0    absent_minded_professor  Professor Keenbean  Richie Rich  /m/02vchl3
# 1    absent_minded_professor                 NaN          NaN         NaN
# 2    absent_minded_professor                 NaN          NaN         NaN
# 3    absent_minded_professor                 NaN          NaN         NaN
# 4    absent_minded_professor                 NaN          NaN         NaN
# ..                       ...                 ...          ...         ...
# 496                young_gun                 NaN          NaN         NaN
# 497                young_gun                 NaN          NaN         NaN
# 498                young_gun                 NaN          NaN         NaN
# 499                young_gun                 NaN          NaN         NaN
# 500                young_gun                 NaN          NaN         NaN
#
#                actor
# 0    Michael McShane
# 1                NaN
# ...
