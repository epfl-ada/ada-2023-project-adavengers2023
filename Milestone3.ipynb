# %% [markdown]
# # Milestone 2 - Adavengers 2023

# %% [markdown]
# # Importing data

# %%
#Library Imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
from scipy import stats
from scipy.stats import ttest_ind
from statsmodels.stats import diagnostic
import re
import gensim
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity
import nltk
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
metadata_headers = ["Wikipedia_ID", "Freebase_ID", "Movie_name" , "Release_date", "box_office_revenue", "runtime", "languages","countries", "genres"]
dfmetadata = pd.read_csv('data/movie.metadata.tsv',sep='\t',header =None, names =metadata_headers)
#dfmetadata.head()

#Reading in the Data
dfsummaries=pd.read_table('data/plot_summaries.txt',header=None,names=["Wikipedia_ID","Summary"])
#dfsummaries.head()
character_head = ["Wikipedia_ID","Freebase_ID", "Release_date", "Character_name", "Actor_date_of_birth", "Gender", "Height", "Ethnicity", "Actor_name", "Age","Freebase_character/actor_map_ID", "Freebase_character_ID", "Freebase_actor_ID"]
dfcharacter =pd.read_csv('data/character.metadata.tsv',sep='\t',header =None, names =character_head)

# %% [markdown]
# In this milestone, we will get acquainted with the data, preprocess it and do necessary descriptive statistics tasks. We will also plan our future analysis in detail and describe, as well as test, proposed methodologies.

# %% [markdown]
# # Cleaning Data

# %% [markdown]
# ## 1) Cleaning Summaries Data

# %%
#Checking if the Wikipedia_IDs in summaries are the same as in Metadata by randomly checking an id (31186339)
print(dfsummaries[dfsummaries["Wikipedia_ID"]==31186339]["Summary"])
print(dfmetadata[dfmetadata["Wikipedia_ID"]==31186339]["Movie_name"])
# Out:
# 1    The nation of Panem consists of a wealthy Capi...
# Name: Summary, dtype: object
# 78373    The Hunger Games
# Name: Movie_name, dtype: object

# %%
#Checking if there are NaNs
print(dfsummaries["Wikipedia_ID"].hasnans) #There are no NaNs.
print(dfsummaries["Summary"].hasnans) #There are no NaNs.
# Out:
# False
# False

# %%
#Checking if there are double entries and removing them
print(dfsummaries["Wikipedia_ID"].is_unique) #This is true, nice!
print(dfsummaries["Summary"].is_unique) #This is false
dfsummaries.drop_duplicates(['Summary'],inplace=True)
print(dfsummaries["Summary"].is_unique) 
#Now we can see there are no more duplicates (remember to do same for metadata!)
# Out:
# True
# True
# True

# %%
#Another thing we could do is look at the type of the data. 
#The IDs should all be positive integers, the summaries all str.
dfsummaries.dtypes #We can see that this is the case
# Out:
# Wikipedia_ID       int64
# Summary           object
# Summary_Length     int64
# dtype: object

# %%
#Checking if we have negative values for ID
dfsummaries["Wikipedia_ID"].min() #Nice! They're all positive.
# Out:
# 330

# %%
#Checking how many entries there are
print("number of summary entries:",len(dfsummaries))
print("number of metadata entries:",len(dfmetadata)) 
#We can see that there is not a summary for every movie but only about half.
# Out:
# number of summary entries: 42295
# number of metadata entries: 81741

# %%
#Check the lengths of the summaries (we can see that there is a great spread.)
dfsummaries["Summary_Length"]=dfsummaries['Summary'].apply(lambda x: len(x))
print("The length of summaries ranges from %d to %d characters." %(dfsummaries["Summary_Length"].min(),dfsummaries["Summary_Length"].max()))
# Out:
# The length of summaries ranges from 99 to 28159 characters.

# %%
#Displayed in a logarithmic histogram, we can see that most movie summaries are short and a few are bigger.
dfsummaries["Summary_Length"].hist(log=True)
plt.title("Frequency of Summary length")
plt.ylabel("Number of summaries (log scale)")
plt.xlabel("Summary length in characters")
# Out:
# Text(0.5, 0, 'Summary length in characters')

# %%
#So, how are the summary lengths actually distributed? Let's find out
print(diagnostic.kstest_normal(dfsummaries['Summary_Length'].values, dist = 'norm'))
print(diagnostic.kstest_normal(dfsummaries['Summary_Length'].values, dist = 'exp'))
#P-avlue < 0.05. The summary lengths are neither normal nor exponentially dist
# Out:
# (0.17600314066454867, 0.0009999999999998899)
# (0.0571594944628687, 0.0009999999999998899)

# %% [markdown]
# There are some summaries much longer than others. Though for now we do the learning on the whole summary dataset as if it was a huge text. This might lead to a bias that the word embedding will learn more from movies with a bigger summary length than those with a shorter. An hypothesis we have is that maybe the longest summaries are the most watched movies and thus the most representative of how the bias between men and women might be seen by the general public of people watching movies. To check this let's do a scatter plot with box office thinking that movies with most data are the most watched movies.

# %% [markdown]
# ## 2 Cleaning Metadata

# %%
dfmetadata.head()
# Out:
#    Wikipedia_ID Freebase_ID  \
# 0        975900   /m/03vyhn
# 1       3196793   /m/08yl5d
# 2      28463795  /m/0crgdbh
# 3       9363483  /m/0285_cd
# 4        261236   /m/01mrr1
#
#                                           Movie_name Release_date  \
# 0                                     Ghosts of Mars   2001-08-24
# 1  Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 2                                        Brun bitter         1988
# 3                                   White Of The Eye         1987
# 4                                  A Woman in Flames         1983
#
#    box_office_revenue  runtime                           languages  \
# 0          14010832.0     98.0  {"/m/02h40lc": "English Language"}
# 1                 NaN     95.0  {"/m/02h40lc": "English Language"}
# 2                 NaN     83.0  {"/m/05f_3": "Norwegian Language"}
# 3                 NaN    110.0  {"/m/02h40lc": "English Language"}
# 4                 NaN    106.0   {"/m/04306rv": "German Language"}
#
#                                    countries  \
# 0  {"/m/09c7w0": "United States of America"}
# 1  {"/m/09c7w0": "United States of America"}
# 2                     {"/m/05b4w": "Norway"}
# 3             {"/m/07ssc": "United Kingdom"}
# 4                    {"/m/0345h": "Germany"}
#
#                                               genres
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1  {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 2  {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 3  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 4                            {"/m/07s9rl0": "Drama"}

# %% [markdown]
# #### Duplicates and NaNs

# %%
#Checking for duplicates
dfmetadata["Wikipedia_ID"].is_unique
dfmetadata["Freebase_ID"].is_unique
# Out:
# True

# %%
#Checking for NaNs using the Non-Null Count
dfmetadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81741 entries, 0 to 81740
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Wikipedia_ID        81741 non-null  int64
#  1   Freebase_ID         81741 non-null  object
#  2   Movie_name          81741 non-null  object
#  3   Release_date        74839 non-null  object
#  4   box_office_revenue  8401 non-null   float64
#  5   runtime             61291 non-null  float64
#  6   languages           81741 non-null  object
#  7   countries           81741 non-null  object
#  8   genres              81741 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 5.6+ MB

# %%
(len(dfmetadata)-dfmetadata["box_office_revenue"].isna().sum()) /len(dfmetadata)
#We can see that we only have box office revenue values for around 10% of the movie data!
# Out:
# 0.1027758407653442

# %% [markdown]
# We can see that there are some NaNs for the release date and the runtime. Especially, there seem to be alot of NaNs for box office revenue!
# This is important as it might affect the feasibility of answering the question if the amount of women in a movie has an effect on box office revenue. We kept the research question in our proposal as an additional question to maybe explore in the end if we have the time. In that case we would also consider incorporating additional data.

# %% [markdown]
# #### Release Dates

# %% [markdown]
# We can see that the release Dates are sometimes written in a date format 2000-02-16 and sometimes it is just the year. In order to have uniform dates, we choose only the year. Since we are looking at longer timespans, we think the year is more important than the date

# %%
def only_year(date):
    date = str(date)
    if len(date) == 4:
        return date
    else:
        return date[:4]
    date=int(date)

# Apply the function to standardize dates
dfmetadata['test'] = dfmetadata['Release_date'].apply(only_year)

dfmetadata
# Out:
#        Wikipedia_ID Freebase_ID  \
# 0            975900   /m/03vyhn
# 1           3196793   /m/08yl5d
# 2          28463795  /m/0crgdbh
# 3           9363483  /m/0285_cd
# 4            261236   /m/01mrr1
# ...             ...         ...
# 81736      35228177  /m/0j7hxnt
# 81737      34980460  /m/0g4pl34
# 81738       9971909  /m/02pygw1
# 81739        913762   /m/03pcrp
# 81740      12476867  /m/02w7zz8
#
#                                               Movie_name Release_date  \
# 0                                         Ghosts of Mars   2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 2                                            Brun bitter         1988
# 3                                       White Of The Eye         1987
# 4                                      A Woman in Flames         1983
# ...                                                  ...          ...
# 81736                           Mermaids: The Body Found   2011-03-19
# 81737                                            Knuckle   2011-01-21
# 81738                                  Another Nice Mess   1972-09-22
# 81739  The Super Dimension Fortress Macross II: Lover...   1992-05-21
# 81740                                            Spliced         2002
#
#        box_office_revenue  runtime                           languages  \
# 0              14010832.0     98.0  {"/m/02h40lc": "English Language"}
# 1                     NaN     95.0  {"/m/02h40lc": "English Language"}
# 2                     NaN     83.0  {"/m/05f_3": "Norwegian Language"}
# 3                     NaN    110.0  {"/m/02h40lc": "English Language"}
# 4                     NaN    106.0   {"/m/04306rv": "German Language"}
# ...                   ...      ...                                 ...
# 81736                 NaN    120.0  {"/m/02h40lc": "English Language"}
# 81737                 NaN     96.0  {"/m/02h40lc": "English Language"}
# 81738                 NaN     66.0  {"/m/02h40lc": "English Language"}
# 81739                 NaN    150.0   {"/m/03_9r": "Japanese Language"}
# 81740                 NaN     86.0  {"/m/02h40lc": "English Language"}
#
#                                                countries  \
# 0              {"/m/09c7w0": "United States of America"}
# 1              {"/m/09c7w0": "United States of America"}
# 2                                 {"/m/05b4w": "Norway"}
# 3                         {"/m/07ssc": "United Kingdom"}
# 4                                {"/m/0345h": "Germany"}
# ...                                                  ...
# 81736          {"/m/09c7w0": "United States of America"}
# 81737  {"/m/03rt9": "Ireland", "/m/07ssc": "United Ki...
# 81738          {"/m/09c7w0": "United States of America"}
# 81739                              {"/m/03_3d": "Japan"}
# 81740                            {"/m/0d060g": "Canada"}
#
#                                                   genres  test
# 0      {"/m/01jfsb": "Thriller", "/m/06n90": "Science...  2001
# 1      {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...  2000
# 2      {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...  1988
# 3      {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...  1987
# 4                                {"/m/07s9rl0": "Drama"}  1983
# ...                                                  ...   ...
# 81736                            {"/m/07s9rl0": "Drama"}  2011
# 81737  {"/m/03bxz7": "Biographical film", "/m/07s9rl0...  2011
# 81738       {"/m/06nbt": "Satire", "/m/01z4y": "Comedy"}  1972
# 81739  {"/m/06n90": "Science Fiction", "/m/0gw5n2f": ...  1992
# 81740  {"/m/01jfsb": "Thriller", "/m/03npn": "Horror"...  2002
#
# [81741 rows x 10 columns]

# %%
dfmetadata.boxplot(column= "runtime")
plt.title("runtime of movies")
# Out:
# Text(0.5, 1.0, 'runtime of movies')

# %% [markdown]
# There are some extreme values. A film 8000 minutes long must be quite boring. Let's look at those data.

# %%
dfmetadata.loc[dfmetadata["runtime"]>8000,:]
# Out:
#        Wikipedia_ID Freebase_ID            Movie_name Release_date  \
# 12804      10815585  /m/02qqy23        Zero Tolerance         1995
# 62962      32441022  /m/0gyr803  Modern Times Forever          NaN
# 71100      25345684  /m/09gqhh3             Cinématon         2011
#
#        box_office_revenue    runtime                           languages  \
# 12804                 NaN  1079281.0  {"/m/02h40lc": "English Language"}
# 62962                 NaN    14400.0                                  {}
# 71100                 NaN     9360.0   {"/m/064_8sq": "French Language"}
#
#                                        countries  \
# 12804  {"/m/09c7w0": "United States of America"}
# 62962                                         {}
# 71100                    {"/m/0f8l9c": "France"}
#
#                                                   genres  test
# 12804  {"/m/01jfsb": "Thriller", "/m/0lsxr": "Crime F...  1995
# 62962                        {"/m/0jtdp": "Documentary"}   nan
# 71100  {"/m/0424mc": "Experimental film", "/m/0jtdp":...  2011

# %% [markdown]
# After a quick look on internet (https://en.wikipedia.org/wiki/Zero_Tolerance_(1994_film)) we noticed that the runtime of the longer movie is actually of 94 minutes which is much shorter than the indicated runtime we thus replace the abberant value. For the other high values we just change them to Nan.

# %%
dfmetadata.loc[12804, ["runtime"]] =  94
#We subjectively decide that a movie longer than 10 hours is to long and it's an error in the data
dfmetadata.loc[dfmetadata["runtime"]>600,:] = np.NaN

# %%
dfmetadata.boxplot(column= "runtime")
plt.title("Runtime of the movies")
plt.ylabel("Runtime in minutes")
# Out:
# Text(0, 0.5, 'Runtime in minutes')

# %% [markdown]
# ## 3) Cleaning character data

# %% [markdown]
# First let's have a quick look at the data.

# %%
dfcharacter
# Out:
#         Wikipedia_ID Freebase_ID Release_date              Character_name  \
# 0             975900   /m/03vyhn   2001-08-24                    Akooshay
# 1             975900   /m/03vyhn   2001-08-24  Lieutenant Melanie Ballard
# 2             975900   /m/03vyhn   2001-08-24         Desolation Williams
# 3             975900   /m/03vyhn   2001-08-24          Sgt Jericho Butler
# 4             975900   /m/03vyhn   2001-08-24             Bashira Kincaid
# ...              ...         ...          ...                         ...
# 450664        913762   /m/03pcrp   1992-05-21                      Elensh
# 450665        913762   /m/03pcrp   1992-05-21                      Hibiki
# 450666      28308153  /m/0cp05t9         1957                         NaN
# 450667      28308153  /m/0cp05t9         1957                         NaN
# 450668      28308153  /m/0cp05t9         1957                         NaN
#
#        Actor_date_of_birth Gender  Height   Ethnicity          Actor_name  \
# 0               1958-08-26      F   1.620         NaN      Wanda De Jesus
# 1               1974-08-15      F   1.780  /m/044038p  Natasha Henstridge
# 2               1969-06-15      M   1.727     /m/0x67            Ice Cube
# 3               1967-09-12      M   1.750         NaN       Jason Statham
# 4               1977-09-25      F   1.650         NaN         Clea DuVall
# ...                    ...    ...     ...         ...                 ...
# 450664             1970-05      F     NaN         NaN  Dorothy Elias-Fahn
# 450665          1965-04-12      M     NaN         NaN       Jonathan Fahn
# 450666          1941-11-18      M   1.730   /m/02w7gg      David Hemmings
# 450667                 NaN    NaN     NaN         NaN    Roberta Paterson
# 450668                 NaN    NaN     NaN         NaN         John Rogers
#
#          Age Freebase_character/actor_map_ID Freebase_character_ID  \
# 0       42.0                      /m/0bgchxw            /m/0bgcj3x
# 1       27.0                       /m/0jys3m            /m/0bgchn4
# 2       32.0                       /m/0jys3g            /m/0bgchn_
# 3       33.0                      /m/02vchl6            /m/0bgchnq
# 4       23.0                      /m/02vbb3r            /m/0bgchp9
# ...      ...                             ...                   ...
# 450664   NaN                      /m/0kr406c            /m/0kr406h
# 450665  27.0                      /m/0kr405_            /m/0kr4090
# 450666  15.0                      /m/0g8ngmc                   NaN
# 450667   NaN                      /m/0g8ngmj                   NaN
# 450668   NaN                      /m/0g8ngmw                   NaN
#
#        Freebase_actor_ID
# 0             /m/03wcfv7
# 1              /m/0346l4
# 2             /m/01vw26l
# 3              /m/034hyc
# 4              /m/01y9xg
# ...                  ...
# 450664         /m/0b_vcv
# 450665         /m/0bx7_j
# 450666         /m/022g44
# 450667        /m/0g8ngmm
# 450668        /m/0btz19d
#
# [450669 rows x 13 columns]

# %%
dfcharacter.describe()
# Out:
#        Wikipedia_ID         Height            Age
# count  4.506690e+05  154824.000000  292556.000000
# mean   1.396975e+07       1.788893      37.788523
# std    1.079662e+07       4.379940      20.587870
# min    3.300000e+02       0.610000   -7896.000000
# 25%    3.759292e+06       1.676400      28.000000
# 50%    1.189065e+07       1.750000      36.000000
# 75%    2.366501e+07       1.830000      47.000000
# max    3.750192e+07     510.000000     103.000000

# %% [markdown]
# #### Height
# We see that the maximum height is 510 which doesn't make sense. We look at the characters with a height above 2m75 as it is the height of the tallest person registered on the guinness world records.

# %%
display(dfcharacter[dfcharacter.Height>2.75])
# Out:
#         Wikipedia_ID Freebase_ID Release_date        Character_name  \
# 21619        1291587   /m/04qk12   2004-09-01         young Georgie
# 49659       30865068   /m/02ml14   1998-10-15                   NaN
# 59719       12206655  /m/02vvw24          NaN               Dominic
# 104140      17999628  /m/047n_2q         1998                   NaN
# 205679       1373475   /m/04xmx8   2003-08-15        Jackal Johnson
# 219383        179326   /m/018gq3   1996-11-18               Herbert
# 301653       4667507   /m/0cg9n6   2001-11-29                   NaN
# 316621       3915041   /m/0b6lyp         2002                   NaN
# 341890      29290087  /m/0b3w9mr   1997-04-07                   NaN
# 360967      14413223  /m/03d2rnl   2012-04-20        Young Punk Guy
# 369731      33945838  /m/0hn8wrq   2012-09-29            Max Loflin
# 380739       4738411   /m/0ckr7s   1993-12-05  Darien - Tuxedo Mask
# 393292       1244822   /m/04lq2l   2003-01-23                   NaN
# 406151       4578386   /m/0c9sj8   2004-04-06                   NaN
# 427957       4738587   /m/0ckrgs   1994-12-04           Tuxedo Mask
#
#        Actor_date_of_birth Gender  Height   Ethnicity      Actor_name   Age  \
# 21619           1986-03-13      M   180.0  /m/0dc58y8    Zohren Weiss  18.0
# 49659           1972-12-06      M   510.0         NaN   Vince Corazza  25.0
# 59719           1986-03-13      M   180.0  /m/0dc58y8    Zohren Weiss   NaN
# 104140          1972-12-06      M   510.0         NaN   Vince Corazza  25.0
# 205679          1972-12-06      M   510.0         NaN   Vince Corazza  30.0
# 219383          1986-03-13      M   180.0  /m/0dc58y8    Zohren Weiss  10.0
# 301653          1972-12-06      M   510.0         NaN   Vince Corazza  28.0
# 316621          1972-12-06      M   510.0         NaN   Vince Corazza  29.0
# 341890          1972-12-06      M   510.0         NaN   Vince Corazza  24.0
# 360967          1986-03-13      M   180.0  /m/0dc58y8    Zohren Weiss  26.0
# 369731                 NaN      M   510.0         NaN  Benedict Smith   NaN
# 380739          1972-12-06      M   510.0         NaN   Vince Corazza  20.0
# 393292          1972-12-06      M   510.0         NaN   Vince Corazza  30.0
# 406151          1972-12-06      M   510.0         NaN   Vince Corazza  31.0
# 427957          1972-12-06      M   510.0         NaN   Vince Corazza  21.0
#
#        Freebase_character/actor_map_ID Freebase_character_ID Freebase_actor_ID
# 21619                       /m/0k276dx            /m/0k276dz        /m/0bggwvl
# 49659                       /m/0n9ld0y                   NaN         /m/08hqh0
# 59719                       /m/0k276dq            /m/0h8hcr1        /m/0bggwvl
# 104140                      /m/0cg31bd                   NaN         /m/08hqh0
# 205679                      /m/02vbm0k            /m/0h60xk7         /m/08hqh0
# 219383                      /m/0bggwv8            /m/0bggwvc        /m/0bggwvl
# 301653                      /m/0cg0zwp                   NaN         /m/08hqh0
# 316621                      /m/02vc5p5                   NaN         /m/08hqh0
# 341890                      /m/0gvwy8x                   NaN         /m/08hqh0
# 360967                      /m/0m4q87d            /m/0k9tfs8        /m/0bggwvl
# 369731                      /m/0n3kptl            /m/0n3kptp        /m/0n3kptx
# 380739                      /m/0bmz820            /m/0lyzygr         /m/08hqh0
# 393292                      /m/0bfm1b6                   NaN         /m/08hqh0
# 406151                      /m/03lj_70                   NaN         /m/08hqh0
# 427957                      /m/0lyz8r1             /m/01_7kc         /m/08hqh0

# %% [markdown]
# We notice that most values for height are in meters and somes are in centimeters and some are of 510. However there are only 15 outliers above 2.75 which are mostly the same actors. We considered changing Zohren Weiss height to 1m80 but as we don't find on internet there true height to check if it was this we are just going to remove it. Moreover we probably won't use Height so we just change the values to Nan.

# %%
dfcharacter.loc[:,["Height"]] = dfcharacter.loc[:,["Height"]].mask(dfcharacter["Height"] >2.75)
dfcharacter.Height.describe()
# Out:
# count    154809.000000
# mean          1.748177
# std           0.106249
# min           0.610000
# 25%           1.676400
# 50%           1.750000
# 75%           1.830000
# max           2.356000
# Name: Height, dtype: float64

# %% [markdown]
# #### Age

# %% [markdown]
# We notice negative age which doesn't make sense. When we check on the imbd it correspond to error in the birth date entry thus we transform the age and the birth date to Nan when negative values are found.

# %%
dfcharacter.loc[:,["Age","Actor_date_of_birth"]] = dfcharacter.loc[:,["Age","Actor_date_of_birth"]].mask(dfcharacter["Age"] <0)
dfcharacter.Age.describe()
# Out:
# count    292175.000000
# mean         37.890901
# std          14.085909
# min           0.000000
# 25%          28.000000
# 50%          36.000000
# 75%          47.000000
# max         103.000000
# Name: Age, dtype: float64

# %% [markdown]
# The minimum age is now at 0 which corresponds to baby born this year so we are happy. Let's now groupby gender to check whether there are differences between the genders in the data that can be cofounders in our analysis.

# %% [markdown]
# #### Difference between genders

# %%
Grouped_gender = dfcharacter.groupby("Gender")
Grouped_gender.Age.describe()
# Out:
#            count       mean        std  min   25%   50%   75%    max
# Gender
# F        99124.0  32.956055  13.376106  0.0  24.0  30.0  40.0   99.0
# M       191277.0  40.469717  13.749781  0.0  31.0  39.0  49.0  103.0

# %%
sns.boxplot(data =dfcharacter, x = "Gender", y = "Age" )
plt.title("Actors age")
plt.ylabel("Age in years")
# Out:
# Text(0, 0.5, 'Age in years')

# %% [markdown]
# We observe a difference between male and female age let's see if it's statistically significant.

# %%
ttest_ind( dfcharacter.loc[dfcharacter['Gender'] == "M", 'Age'].dropna(),dfcharacter.loc[dfcharacter['Gender'] == "F", 'Age'].dropna())
# Out:
# TtestResult(statistic=140.92509242040052, pvalue=0.0, df=290399.0)

# %% [markdown]
# The p-value is lower than 0.05 thus we can reject the null hypothesis that the two distributions have the same mean. The statistics is positive thus we can say than in average man actors are older than women. This is a well known fact but it is always interesting to observe that women actress are in average younger than man actors. Moreover we need to keep this information in mind when we analyze the adjectives as women are younger than men in average because younger people can be described with different adjectives than older people.

# %% [markdown]
# ## 4) Describing Summaries and Movie Metadata

# %%
movie_merged = dfmetadata.merge(dfsummaries,how ='outer')
movie_merged["summary_presence"] = (~movie_merged["Summary"].isna()).astype(int)

# %% [markdown]
# Let's see if the dataset with summaries is representative of the actual movie dataset.

# %%
sns.boxplot(data =movie_merged, x = "summary_presence", y = "runtime" )
plt.title("Runtime of movies")
plt.ylabel("Runtime in minutes")
plt.xlabel("Presence of summary")
# Out:
# Text(0.5, 0, 'Presence of summary')

# %% [markdown]
# We notice that there are very short movies. Let's see if the runtime of a movie as an influence on the summary length to be sure the model doesn't train to much short movies that aren't necessarely representative of the watched movies by the public.

# %%
runtime_and_summary_length = movie_merged[(~movie_merged['Summary_Length'].isna()) & (~movie_merged['runtime'].isna())]
len(runtime_and_summary_length)
# Out:
# 35563

# %%
sns.lmplot(data = runtime_and_summary_length, x= "Summary_Length", y = "runtime")
plt.title("Runtime in function of summary length")
# Out:
# d:\Anaconda3\envs\ADA\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(0.5, 1.0, 'Runtime in function of summary length')

# %%
sns.lmplot(data = runtime_and_summary_length, x= "Summary_Length", y = "runtime")
plt.yscale("log") 
plt.ylabel("Runtime in minutes (log scale)")
plt.title("Runtime in function of summary length")
# Out:
# d:\Anaconda3\envs\ADA\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(0.5, 1.0, 'Runtime in function of summary length')

# %%
print(stats.pearsonr(runtime_and_summary_length['Summary_Length'],runtime_and_summary_length['runtime']))
# Out:
# PearsonRResult(statistic=0.16021729056699072, pvalue=4.101751708932357e-203)

# %% [markdown]
#  When we look at the pearson correlation we observe a small positive correlation which is what was expected. The runtime actually has an effect on the summary length.The longest movies have longer summaries and thus bigger impact on our model which is normal.
# The runtime anyway is not statiscally different between movies containing a summary and movies that don't thus the dataset with summaries is representative of the total dataset in runtime period.

# %%
ttest_ind(movie_merged.loc[movie_merged['summary_presence'] == 1, 'runtime'].dropna(),movie_merged.loc[movie_merged['summary_presence'] == 0, 'runtime'].dropna())
# Out:
# TtestResult(statistic=38.6787260170193, pvalue=0.0, df=61256.0)

# %% [markdown]
# The p-value is lower than 0.5 thus we can exclude the null hypothesis that the movie with a summary and the movies without follow the same distribution for runtime. The statistic is positive meaning the movies which contains a summary have a longer runtime which is expected. However the dataset with summaries is thus not representative of the general dataset for runtime. As we consider longer film to be more watched we won't try to adapt the data but must keep this in mind.

# %% [markdown]
# #### Box office revenue analysis

# %% [markdown]
# Let's look if the movies with summary are representative of the movies the most watched. By looking at the box office revenue.
# The longer the summary the more the training will be done on it. Thus we want to check if longers summaries are more watched.

# %%
sns.boxplot(data =movie_merged, x = "summary_presence", y = "box_office_revenue" )
plt.title("Box office revenue in function of summary presence")
plt.ylabel("Box office revenue")
plt.xlabel("Presence of summary")
# Out:
# Text(0.5, 0, 'Presence of summary')

# %% [markdown]
# We notice that there are much more movies when summaries are in the dataset. Furthermore the the box office revenue is mainly higher for movies with a summary. Let's see if it's statistically significant.

# %%
ttest_ind(movie_merged.loc[movie_merged['summary_presence'] == 1, 'box_office_revenue'].dropna(),movie_merged.loc[movie_merged['summary_presence'] == 0, 'box_office_revenue'].dropna())
# Out:
# TtestResult(statistic=9.444435849095447, pvalue=4.544470664944394e-21, df=8398.0)

# %% [markdown]
# The p-value is lower than 0.5 thus we can exclude the null hypothesis that the movie with a summary and the movies without follow the same distribution for box-office revenue. The movie with a summary have in average bigger box-office which is great news because it means they are more watched

# %%
box_office_and_summary_length = movie_merged[(~movie_merged['Summary_Length'].isna()) & (~movie_merged['box_office_revenue'].isna())]
print(f'There are {len(box_office_and_summary_length)} movies which contain values for the summary and the box office revenue')
# Out:
# There are 7586 movies which contain values for the summary and the box office revenue

# %%
sns.lmplot(data = box_office_and_summary_length, x= "Summary_Length", y = "box_office_revenue")
plt.title("Box office revenue in function of summary length")
plt.ylabel("Box office revenue")
plt.xlabel("Summary length in characters")
# Out:
# d:\Anaconda3\envs\ADA\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(0.5, 29.140624999999986, 'Summary length in characters')

# %% [markdown]
# There are some very big values for box office we can use log scale to have a better visualisation of the data for smaller box office.

# %%
sns.lmplot(data = box_office_and_summary_length, x= "Summary_Length", y = "box_office_revenue")
plt.yscale("log") 
plt.title("Box office revenue in function of summary length")
plt.ylabel("Box office revenue (log scale)")
plt.xlabel("Summary length in characters")
# Out:
# d:\Anaconda3\envs\ADA\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(0.5, 29.140624999999986, 'Summary length in characters')

# %%
print(stats.pearsonr(box_office_and_summary_length['Summary_Length'],box_office_and_summary_length['box_office_revenue']))
# Out:
# PearsonRResult(statistic=0.25136571070242975, pvalue=1.1821237120673286e-109)

# %% [markdown]
# There is a small positive correlation between box office revenue and the summary length. Which is good news because the longer the summary the more our algorithm will train on it. However there are huge differences between the length of our summaries which might be lead to bias in the learning. To resolve this we can do a weighted learning and give less weigth to the movies with big summaries but this has not yet been implemented. Box office revenues are a good indication of how much a movie is watched thus of how influent it is on the general public.

# %%
summary_and_movie = dfmetadata.merge(dfsummaries,how ='right')

# %% [markdown]
# ## 5) Summary and character cleaning

# %% [markdown]
# We want to look if the movies with summaries are the ones which also have characters

# %%
print(f'There are {len(summary_and_movie)} movies that have summary data')
nb_sumarry_and_character = len(summary_and_movie[summary_and_movie["Freebase_ID"].isin(dfcharacter["Freebase_ID"])])
print(f'There are {nb_sumarry_and_character} movies which contain data for characters and summary' )
# Out:
# There are 42295 movies that have summary data
# There are 37763 movies which contain data for characters and summary

# %% [markdown]
# However when we look at it in detail some of the character data don't have character_name in it as we will need this data it might be an issue if we don't have enough data and we might need to rethink our strategy for detecting the gender of characters. To replace it by he or she.

# %%
dfcharacter_in_summary = dfcharacter[dfcharacter["Freebase_ID"].isin(summary_and_movie["Freebase_ID"])]
print(f'There are {len(dfcharacter_in_summary)} characters in movies that also have a summary')
character_with_name = dfcharacter_in_summary[~dfcharacter_in_summary["Character_name"].isna()]
print(f'There are {len(character_with_name)} characters with a name in movies that also have a summary')
print(f'There is {len(character_with_name)/len(dfcharacter)} percent of characters of which we can use the names')
# Out:
# There are 308367 characters in movies that also have a summary
# There are 142353 characters with a name in movies that also have a summary
# There is 0.31587040599641864 percent of characters of which we can use the names

# %%
movie_with_char_names = len(summary_and_movie[summary_and_movie["Freebase_ID"].isin(character_with_name["Freebase_ID"])])
print(f'{movie_with_char_names} movies have data for character name')
print(f'{movie_with_char_names/len(dfmetadata)} percent of the movie have data about the character names')
# Out:
# 23059 movies have data for character name
# 0.2820983349848913 percent of the movie have data about the character names

# %% [markdown]
# This is not a lot of movies but we will anyway proceed with the analysis on this data. We decided it should be enough to work on. If however we realize later in the project that we are too short on data for the learning to be significant we will try to extract it on imbd.

# %% [markdown]
# ## 6) Cleaning cluster data

# %% [markdown]
# In this step, we want to begin the initial investigations for the research question which character types women usually play.

# %%
#We can see that the infos about character, movie, id and actor are all in one column.
df_clusters_initial=pd.read_table('data/tvtropes.clusters.txt',header=None)
df_clusters_initial
# Out:
#                            0  \
# 0    absent_minded_professor
# 1    absent_minded_professor
# 2    absent_minded_professor
# 3    absent_minded_professor
# 4    absent_minded_professor
# ..                       ...
# 496                young_gun
# 497                young_gun
# 498                young_gun
# 499                young_gun
# 500                young_gun
#
#                                                      1
# 0    {"char": "Professor Philip Brainard", "movie":...
# 1    {"char": "Professor Keenbean", "movie": "Richi...
# 2    {"char": "Dr. Reinhardt Lane", "movie": "The S...
# 3    {"char": "Dr. Harold Medford", "movie": "Them!...
# 4    {"char": "Daniel Jackson", "movie": "Stargate"...
# ..                                                 ...
# 496  {"char": "Morgan Earp", "movie": "Tombstone", ...
# 497  {"char": "Colorado Ryan", "movie": "Rio Bravo"...
# 498  {"char": "Tom Sawyer", "movie": "The League of...
# 499  {"char": "William H. 'Billy the Kid' Bonney", ...
# 500  {"char": "Jake", "movie": "Silverado", "id": "...
#
# [501 rows x 2 columns]

# %%
#The infos are stored in string representations of dictionaries
example_entry = df_clusters_initial[1][1]
print(type(example_entry))
# Out:
# <class 'str'>

# %%
#We need to turn the string representations of dictionaries into actual dictionaries
#(The if statement is just so the cell can be run without having run the previous cells, to avoid confusion)
import ast
if type(example_entry)==str: 
    df_clusters_initial[1]=df_clusters_initial[1].apply(lambda x: ast.literal_eval(x))

# %%
#Now, we can separate the values in the dictionaries to different columns
df_dict = pd.json_normalize(df_clusters_initial[1])

# %%
#Adding the separated dictionary values to the initial df
dfclusters = pd.concat([df_clusters_initial.drop(1,axis=1), df_dict], axis=1)

# %%
dfclusters=dfclusters.rename(columns={0:"type",'actor':'Actor_name','id':'Freebase_character/actor_map_ID'})
dfclusters
# Out:
#                         type                               char  \
# 0    absent_minded_professor          Professor Philip Brainard
# 1    absent_minded_professor                 Professor Keenbean
# 2    absent_minded_professor                 Dr. Reinhardt Lane
# 3    absent_minded_professor                 Dr. Harold Medford
# 4    absent_minded_professor                     Daniel Jackson
# ..                       ...                                ...
# 496                young_gun                        Morgan Earp
# 497                young_gun                      Colorado Ryan
# 498                young_gun                         Tom Sawyer
# 499                young_gun  William H. 'Billy the Kid' Bonney
# 500                young_gun                               Jake
#
#                                      movie Freebase_character/actor_map_ID  \
# 0                                  Flubber                       /m/0jy9q0
# 1                              Richie Rich                      /m/02vchl3
# 2                               The Shadow                       /m/0k6fkc
# 3                                    Them!                       /m/0k6_br
# 4                                 Stargate                       /m/0k3rhh
# ..                                     ...                             ...
# 496                              Tombstone                       /m/0k776f
# 497                              Rio Bravo                       /m/0k2kqg
# 498  The League of Extraordinary Gentlemen                       /m/0k5nsh
# 499                          Young Guns II                      /m/03lrjk0
# 500                              Silverado                       /m/0k39jj
#
#           Actor_name
# 0     Robin Williams
# 1    Michael McShane
# 2       Ian McKellen
# 3       Edmund Gwenn
# 4       James Spader
# ..               ...
# 496      Bill Paxton
# 497     Ricky Nelson
# 498       Shane West
# 499   Emilio Estevez
# 500    Kevin Costner
#
# [501 rows x 5 columns]

# %%
#Checking if there are NaN values:
print(dfclusters['type'].hasnans)
print(dfclusters['char'].hasnans)
print(dfclusters['movie'].hasnans)
print(dfclusters['Freebase_character/actor_map_ID'].hasnans)
print(dfclusters['Actor_name'].hasnans)
# Out:
# False
# False
# False
# False
# False

# %% [markdown]
# In order to see which character types are more commonly females and which males we have to merge this with the character metadata dataframe

# %%
#We only need the info on genders from the character df so I do this to avoid having to drop many columns later
clusters_merged = dfclusters.merge(dfcharacter[['Freebase_character/actor_map_ID', 'Gender']],on="Freebase_character/actor_map_ID")
clusters_merged
# Out:
#                         type                               char  \
# 0    absent_minded_professor          Professor Philip Brainard
# 1    absent_minded_professor                 Professor Keenbean
# 2    absent_minded_professor                 Dr. Reinhardt Lane
# 3    absent_minded_professor                 Dr. Harold Medford
# 4    absent_minded_professor                     Daniel Jackson
# ..                       ...                                ...
# 496                young_gun                        Morgan Earp
# 497                young_gun                      Colorado Ryan
# 498                young_gun                         Tom Sawyer
# 499                young_gun  William H. 'Billy the Kid' Bonney
# 500                young_gun                               Jake
#
#                                      movie Freebase_character/actor_map_ID  \
# 0                                  Flubber                       /m/0jy9q0
# 1                              Richie Rich                      /m/02vchl3
# 2                               The Shadow                       /m/0k6fkc
# 3                                    Them!                       /m/0k6_br
# 4                                 Stargate                       /m/0k3rhh
# ..                                     ...                             ...
# 496                              Tombstone                       /m/0k776f
# 497                              Rio Bravo                       /m/0k2kqg
# 498  The League of Extraordinary Gentlemen                       /m/0k5nsh
# 499                          Young Guns II                      /m/03lrjk0
# 500                              Silverado                       /m/0k39jj
#
#           Actor_name Gender
# 0     Robin Williams      M
# 1    Michael McShane      M
# 2       Ian McKellen      M
# 3       Edmund Gwenn      M
# 4       James Spader      M
# ..               ...    ...
# 496      Bill Paxton      M
# 497     Ricky Nelson      M
# 498       Shane West      M
# 499   Emilio Estevez      M
# 500    Kevin Costner      M
#
# [501 rows x 6 columns]

# %%
#grouping by type and gender
types = clusters_merged.groupby(['type', 'Gender']).size().unstack(fill_value=0)

#adding a column for total M+F to see which types are most comon
types['total_count'] = types['F'] + types['M']

#adding a column for the percentage of women
types['F_percentage'] = (types['F'] / (types['F'] + types['M']))*100

# Resetting index to make 'type' a column
types.reset_index(inplace=True)

# %%
types.sort_values(by='F_percentage',ascending=False).head(15)
# Out:
# Gender                type   F  M  total_count  F_percentage
# 44          junkie_prophet   2  0            2    100.000000
# 12               chanteuse   6  0            6    100.000000
# 51                 ophelia   5  0            5    100.000000
# 34              final_girl   6  0            6    100.000000
# 15      classy_cat_burglar   1  0            1    100.000000
# 53             prima_donna   6  0            6    100.000000
# 69             valley_girl   6  0            6    100.000000
# 27             dumb_blonde  10  1           11     90.909091
# 6              broken_bird   4  1            5     80.000000
# 5         brainless_beauty   7  5           12     58.333333
# 37          granola_person   4  4            8     50.000000
# 45                   klutz   1  1            2     50.000000
# 29        eccentric_mentor   2  3            5     40.000000
# 9                    bully   1  2            3     33.333333
# 25                 doormat   1  3            4     25.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6)) 
ax = sns.barplot(x='type',y="F_percentage", data=types.sort_values(ascending=False,by='F_percentage').head(20))
ax = plt.title("Percentage of women represented playing different character types")
ax = plt.ylabel("Percentage of women")
ax = plt.xticks(rotation=90)

# %% [markdown]
# We can see that women are most represented in character types such as "valley girl" or "prima donna", and less in types such as "adventurer archaeologist". However, it is important to note that the clusters data is very short, so this is not very meaningful. Nevertheless, we thought it was interesting to see. Maybe in future analyses we can expand on the different character types or create our own.

# %% [markdown]
# Next, we want to see if the effect of character types on gender they are played by is significant. Since gender is binary (F/M) and character types is categorical, we performed a chi square test:

# %%
#Doing a chi squared test

#Creating contingency table
contingency_table = pd.crosstab(clusters_merged['Gender'], clusters_merged['type'])

#Performing chi squared test
chi2, p_value, _, _ = stats.chi2_contingency(contingency_table)

print(f"Chi-squared statistic: {chi2}")
print(f"P-value: {p_value}")
# Out:
# Chi-squared statistic: 369.8513527525936
# P-value: 5.592160386860096e-42

# %% [markdown]
# We can see that the gender difference when playing different character types is very significant! P-value 5.59e-42 (<<0.05). However, as noted before, the dataset for character types is very small, so this result needs to be taken with a grain of salt.

# %% [markdown]
# ## 7) Women in different movie genres

# %% [markdown]
# Analoug to the previous step, where we started to investigate which character types female actrices usually play, in this step, we start the analysis for the research question how female characters are represented in different movie genres.

# %%
#In order to investigate women in different genres, we need to merge the metadata and character data.
meta_char_merged=dfcharacter[['Freebase_ID','Actor_name','Gender']].merge(dfmetadata[['Freebase_ID','Movie_name','genres']],on="Freebase_ID")

# %% [markdown]
# #Like with the character types in the cluster data, the can see that the genres in the movie metadata are stored string representing a dictionary. We therefore need to change the string representation to dictionary and then create different columns for the genres.

# %%
example_entry1 = meta_char_merged.genres[1]
print(type(example_entry1))
print(example_entry1)
# Out:
# <class 'str'>
# {"/m/01jfsb": "Thriller", "/m/06n90": "Science Fiction", "/m/03npn": "Horror", "/m/03k9fj": "Adventure", "/m/0fdjb": "Supernatural", "/m/02kdv5l": "Action", "/m/09zvmj": "Space western"}

# %%
#First, we need to change the type from a string representation to a dictionary
if type(example_entry1)==str: 
    meta_char_merged.genres=meta_char_merged.genres.apply(lambda x: ast.literal_eval(x))

#Now, we can create a df where the genres are all in different columns
df_dict1 = pd.json_normalize(meta_char_merged.genres)

# %%
df_dict1.head()
# Out:
#   /m/01jfsb         /m/06n90 /m/03npn  /m/03k9fj      /m/0fdjb /m/02kdv5l  \
# 0  Thriller  Science Fiction   Horror  Adventure  Supernatural     Action
# 1  Thriller  Science Fiction   Horror  Adventure  Supernatural     Action
# 2  Thriller  Science Fiction   Horror  Adventure  Supernatural     Action
# 3  Thriller  Science Fiction   Horror  Adventure  Supernatural     Action
# 4  Thriller  Science Fiction   Horror  Adventure  Supernatural     Action
#
#        /m/09zvmj /m/02n4kr /m/03bxz7 /m/07s9rl0  ... /m/0bbctgg /m/0hj3myj  \
# 0  Space western       NaN       NaN        NaN  ...        NaN        NaN
# 1  Space western       NaN       NaN        NaN  ...        NaN        NaN
# 2  Space western       NaN       NaN        NaN  ...        NaN        NaN
# 3  Space western       NaN       NaN        NaN  ...        NaN        NaN
# 4  Space western       NaN       NaN        NaN  ...        NaN        NaN
#
#   /m/06ymb /m/017g5 /m/05b8xy /m/018sjn /m/0g9yrf1 /m/02crcx /m/0jmw6g2  \
# 0      NaN      NaN       NaN       NaN        NaN       NaN        NaN
# 1      NaN      NaN       NaN       NaN        NaN       NaN        NaN
# 2      NaN      NaN       NaN       NaN        NaN       NaN        NaN
# 3      NaN      NaN       NaN       NaN        NaN       NaN        NaN
# 4      NaN      NaN       NaN       NaN        NaN       NaN        NaN
#
#   /m/05453r
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 361 columns]

# %%
#We can see that the headers for genres are IDs, so let's change them to more intuitive headers.
new_column_names = []

#We will take the first most frequent not NaN mode to be the name of the column because this is also the name of the genre
for column in df_dict1.columns:
    name = df_dict1[column].mode()[0]
    new_column_names.append(name)
    
df_dict1.columns=new_column_names

# %%
#Now, we can merge the df with the genre infos to our original dataframe with the rest of the information (movie name, gender etc)
meta_char_merged2 = pd.concat([meta_char_merged.drop('genres',axis=1), df_dict1], axis=1)

# %%
#Next, we are interested in how gender representation varies in different genres
#for this we will count the values in the genre columns
gender_counts_init = meta_char_merged2.drop(['Freebase_ID','Actor_name','Movie_name'],axis=1).groupby('Gender').count()
gender_counts_init
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[64], line 3
#       1 #Next, we are interested in how gender representation varies in different genres
#       2 #for this we will count the values in the genre columns
# ----> 3 gender_counts_init = meta_char_merged2.drop(['Freebase_ID','Actor_name','Movie_name'],axis=1).groupby('Gender').count()
#       4 gender_counts_init
#
# File d:\Anaconda3\envs\ADA\lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File d:\Anaconda3\envs\ADA\lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File d:\Anaconda3\envs\ADA\lib\site-packages\pandas\core\generic.py:4630, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4627     new_axis = axis.take(indexer)
#    4629 bm_axis = self.ndim - axis_num - 1
# -> 4630 new_mgr = self._mgr.reindex_indexer(
#    4631     new_axis,
#    4632     indexer,
#    4633     axis=bm_axis,
#    4634     allow_dups=True,
#    4635     copy=None,
#    4636     only_slice=only_slice,
#    4637 )
#    4638 result = self._constructor(new_mgr)
#    4639 if self.ndim == 1:
#
# File d:\Anaconda3\envs\ADA\lib\site-packages\pandas\core\internals\managers.py:740, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     737     raise IndexError("Requested axis not found in manager")
#     739 if axis == 0:
# --> 740     new_blocks = self._slice_take_blocks_ax0(
#     741         indexer,
#     742         fill_value=fill_value,
#     743         only_slice=only_slice,
#     744         use_na_proxy=use_na_proxy,
#     745     )
#     746 else:
#     747     new_blocks = [
#     748         blk.take_nd(
#     749             indexer,
#    (...)
#     755         for blk in self.blocks
#     756     ]
#
# File d:\Anaconda3\envs\ADA\lib\site-packages\pandas\core\internals\managers.py:898, in BaseBlockManager._slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice, use_na_proxy)
#     896                     blocks.append(nb)
#     897             else:
# --> 898                 nb = blk.take_nd(taker, axis=0, new_mgr_locs=mgr_locs)
#     899                 blocks.append(nb)
#     901 return blocks
#
# File d:\Anaconda3\envs\ADA\lib\site-packages\pandas\core\internals\blocks.py:945, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#     942     allow_fill = True
#     944 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# --> 945 new_values = algos.take_nd(
#     946     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#     947 )
#     949 # Called from three places in managers, all of which satisfy
#     950 #  these assertions
#     951 if isinstance(self, ExtensionBlock):
#     952     # NB: in this case, the 'axis' kwarg will be ignored in the
#     953     #  algos.take_nd call above.
#
# File d:\Anaconda3\envs\ADA\lib\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File d:\Anaconda3\envs\ADA\lib\site-packages\pandas\core\array_algos\take.py:157, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     155     out = np.empty(out_shape, dtype=dtype, order="F")
#     156 else:
# --> 157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
#     162 func(arr, indexer, out, fill_value)
#
# MemoryError: Unable to allocate 1.21 GiB for an array with shape (361, 450516) and data type object

# %%
#We want this to be in a regular dataframe format so we transpose it
gender_counts=gender_counts_init.transpose()

# %%
#Let's add some more interesting columns!
#First, i want one for the total counts to later look at the most common genres
gender_counts['total_count']=gender_counts.F+gender_counts.M
#Next, we are also also interested in the percentage of women
gender_counts['F_percentage']=(gender_counts.F/(gender_counts.F+gender_counts.M))*100

#Finally, we want reset the index so that genre is a normal column:
gender_counts_2=gender_counts.reset_index()
gender_counts_2=gender_counts_2.rename(columns={'index':'Genre'})

gender_counts_2
# Out:
# Gender              Genre      F      M  total_count  F_percentage
# 0                Thriller  21266  48150        69416     30.635588
# 1         Science Fiction   6626  16349        22975     28.840044
# 2                  Horror  11659  21127        32786     35.560910
# 3               Adventure   9715  27064        36779     26.414530
# 4            Supernatural   1951   3299         5250     37.161905
# ..                    ...    ...    ...          ...           ...
# 356               Revenge      2      6            8     25.000000
# 357     Romantic thriller      1      0            1    100.000000
# 358           Chick flick      8     10           18     44.444444
# 359         Buddy Picture      7     29           36     19.444444
# 360         Homoeroticism      0      7            7      0.000000
#
# [361 rows x 5 columns]

# %%
#Finally, we plot the Female Percentage for the 10 most common Genres:

#Create a df for the 10 most common genres
mostcommon=gender_counts_2.sort_values(by='total_count',ascending=False).head(20)
#sort it by female percentage
mostcommon=mostcommon.sort_values(by='F_percentage',ascending=False)

# %%
#Making plot
plt.figure(figsize=(12, 6)) 
ax = sns.barplot(x='Genre',y="F_percentage", data=mostcommon)
ax = plt.title("Percentage of women in most common genres")
ax = plt.ylabel("percentage of women")
ax = plt.xticks(rotation=90)

# %% [markdown]
# Next, we want to see if the gender difference in different genres is significant. We will again perform a chi square test, as gender (M/F) as well as genre are categorical.

# %%
#Doing a chi suqare test

#Creating contingency table:
df_Genre_FM = gender_counts_2[['Genre', 'F', 'M']]
df_pivoted = df_Genre_FM.pivot_table(index='Genre', values=['F', 'M'])
df_contingency = df_pivoted.T

#Removing columns where M or F is zero because else the chi square test doesn't work.
df_contingency = df_contingency.loc[:, ~(df_contingency == 0).any(axis=0)]

df_contingency
#contingency_table = pd.crosstab(gender_counts_2['Genre'], [gender_counts_2['F'], gender_counts_2['M']])

# Performing chi-squared test
chi2, p, dof, expected = stats.chi2_contingency(df_contingency)


print("Chi-square statistic:", chi2)
print("P-value: {:.2e}".format(p_value))
print("Degrees of freedom:", dof)
# Out:
# Chi-square statistic: 18841.717731398014
# P-value: 5.59e-42
# Degrees of freedom: 354

# %% [markdown]
# We can see that the effect of genre on the gender of the actors playing in it is highly significant, as the p-value is 0.00e+00 (<0.05).

# %% [markdown]
# ##  8) Female Character Identities in Synopses

# %% [markdown]
# Now that we have a better grasp of our data and that it's cleaned let's start to try to answer question 1. The first aspect of this question is do movie summaries use different adjectives for women and men?  What personality traits are typically attributed to them? What implicit meanings are conveyed through adjectives used for women?
# For now let's focus on asking ourselves do movie summaries use different adjectives for men and women ?

# %% [markdown]
# ###  Data preprocessing

# %% [markdown]
# The first step we are going to follow is to extract the character names to then be able to change them to the gender of the character. For now we just take the whole character dataset and replace it in the summaries. However this can lead to error for example in the summary used as example the word different  is counted as a male character and is replaced by he while in this context it's not a male character.

# %%
dfcharacter.columns
# Out:
# Index(['Wikipedia_ID', 'Freebase_ID', 'Release_date', 'Character_name',
#        'Actor_date_of_birth', 'Gender', 'Height', 'Ethnicity', 'Actor_name',
#        'Age', 'Freebase_character/actor_map_ID', 'Freebase_character_ID',
#        'Freebase_actor_ID'],
#       dtype='object')

# %%
dfcharacter.iloc[:, [3, 5]].dropna()
df_name_gender = dfcharacter.iloc[:, [3, 5]].dropna()
df_name_gender.columns = ['Name','Gender']
print(df_name_gender.head(5))
# Out:
#                          Name Gender
# 0                    Akooshay      F
# 1  Lieutenant Melanie Ballard      F
# 2         Desolation Williams      M
# 3          Sgt Jericho Butler      M
# 4             Bashira Kincaid      F

# %%
# build a name dict
name_list = dfcharacter.iloc[:, [3]].dropna()
name_list=name_list.squeeze().tolist()
name_dict = set()
for item in list(name_list):
    names = item.split()
    for name in names:
            name_dict.add(name.lower())
len(name_dict)
# Out:
# 68422

# %%
# English vocabulary specific to a certain gender
# female_nouns.txt contains common words that are only used to refer to females, like 'mother'
female_words=set()
with open('data/female_nouns.txt', 'r') as file:
    for line in file:
        words = re.split('[^a-zA-Z]', line)
        for word in words:
            if word:
                female_words.add(word.lower())                
                
# male_nouns.txt contains common words that are only used to refer to males, like 'uncle'     
male_words=set()
with open('data/male_nouns.txt', 'r') as file:
    for line in file:
        words = re.split('[^a-zA-Z]', line)
        for word in words:
            if word:
                male_words.add(word.lower())

# %%
# Define a list of words representing females/males
# females
df_female_name = df_name_gender[df_name_gender['Gender']=='F']['Name']
female_name_dict = set()
for item in df_female_name:
    names = item.split()
    for name in names:
        # remove the names like 'Alice's father' that can have a negative impact on the result
        if not name.lower() in female_words | male_words:
            if not name.lower().endswith("'s"):
                female_name_dict.add(name.lower())
female_cleaned_list = [re.sub('[^a-zA-Z]', '', s) for s in female_name_dict]


# males
df_male_name = df_name_gender[df_name_gender['Gender']=='M']['Name']
male_name_dict = set()
for item in df_male_name:
    names = item.split()
    for name in names:
        if not name.lower() in female_words | male_words:
            if not name.lower().endswith("'s"):
                male_name_dict.add(name.lower())
male_cleaned_list = [re.sub('[^a-zA-Z]', '', s) for s in male_name_dict]

# %%
#some characters have the same family name but different gender,remove the family names
female_name_dict_cleaned = set(female_cleaned_list)
male_name_dict_cleaned = set(male_cleaned_list)

intersection_set = male_name_dict_cleaned & female_name_dict_cleaned
male_name_dict = male_name_dict_cleaned - intersection_set
female_name_dict = female_name_dict_cleaned - intersection_set
cleaned_list = [re.sub('[^a-zA-Z]', '', s) for s in name_dict]
print(len(cleaned_list))
cleaned_list = set(cleaned_list) - intersection_set
print(len(cleaned_list))
# Out:
# 68422
# 53838

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aaugr\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\aaugr\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\aaugr\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# data preprocessing
# Set the stopwords
stop_words = set(stopwords.words('english'))

# a list of words representing females/males
female_names_words = female_words | female_name_dict
male_names_words = male_words | male_name_dict

# remove adjs in the name list
adjs_set = set()
with open('data/common_adjs.txt', 'r') as file:
    for line in file:
        word = line.strip().lower()
        adjs_set.add(word)
female_names_words = female_names_words - adjs_set
male_names_words = male_names_words - adjs_set

# function used to tokenize, replace words representing females with 'she' and males with 'he', and remove stopwords
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    return ['she' if word in female_names_words else 'he' if word in male_names_words else word for word in text.split() if word not in stop_words]

# %%
df_cleaned_summary = dfsummaries["Summary"].apply(lambda x : preprocess_text(x))
documents = list(df_cleaned_summary)
documents

# %%
# code to extract adjs(the outcome is stored in data/adjectives.txt, so you can skip this)
# 
female_name_dict = []
with open('data/female_name_dict1.txt', 'r', encoding='utf-8') as file:
    for line in file:
        female_name_dict.append(line.strip())
female_name_dict=set(female_name_dict)
male_name_dict = []
with open('data/male_name_dict1.txt', 'r', encoding='utf-8') as file:
    for line in file:
        male_name_dict.append(line.strip())
male_name_dict=set(male_name_dict)

# Define a list of words representing females/males
female_names_words = female_words | female_name_dict
male_names_words = male_words | male_name_dict
remove_dict=(stop_words | female_names_words | male_names_words)
#from https://www.merriam-webster.com/thesaurus/

def preprocess_text_adj(text):
    # lower the words and remove punctuation
    text_token = word_tokenize(text)
    tagged = pos_tag(text_token)
    adjectives = [word for word, pos in tagged if (pos.startswith('JJ'))]
    text = [word.lower() for word in adjectives if word.isalpha()]
    # tokenize, replace words representing females with 'she' and males with 'he', and remove stopwords.
    return [word for word in text if word not in remove_dict]



documents_adj= list(dfsummaries["Summary"].apply(lambda x : preprocess_text_adj(x)))

# %%
documents_adj
# Out:
# [[],
#  ['wealthy',
#   'poorer',
#   'past',
#   'annual',
#   'first',
#   'older',
#   'past',
#   'special',
#   'televised',
#   'first',
#   'tempting',
#   'nearby',
#   'poisonous',
#   'dead',
#   'infected',
#   'poisonous',
#   'prolonged',
#   'victorious',
#   'powerful'],
#  ['prison',
#   'earlier',
#   'top',
#   'civil',
#   'former',
#   'dead',
#   'gross',
#   'promising',
#   'funeral',
#   'first',
#   'good',
#   'dead',
#   'whole',
#   'close',
#   'supreme',
#   'hidden',
#   'funeral',
#   'last',
#   'ritual',
#   'peaceful'],
#  ['touting',
#   'several',
#   'gullible',
#   'prefabricated',
#   'notorious',
#   'dead',
#   'last',
#   'first',
#   'local',
#   'previous',
#   'underhanded',
#   'short',
#   'legitimate',
#   'key',
#   'jailed',
#   'small',
#   'elderly',
#   'free',
#   'unaware',
#   'overjoyed',
#   'wherever',
#   'late',
#   'oversized',
#   'true',
#   'angry',
#   'elderly',
#   'secure',
#   'original',
#   'little',
#   'old',
#   'earlier',
#   'necessary',
#   'main',
#   'free'],
#  ['certain',
#   'animal',
#   'subsequent',
#   'true',
#   'public',
#   'stoic',
#   'religious',
#   'new',
#   'circumstantial',
#   'small',
#   'wooden',
#   'seven',
#   'guilty',
#   'guilty',
#   'guilty',
#   'suspended',
#   'english',
#   'small'],
#  ['secret',
#   'main',
#   'secret',
#   'investigative',
#   'third',
#   'suspicious',
#   'previous',
#   'dead',
#   'first',
#   'first',
#   'unfaithful'],
#  ['young',
#   'outside',
#   'bitter',
#   'closer',
#   'good',
#   'full',
#   'great',
#   'unstable',
#   'new',
#   'dilapidated',
#   'large',
#   'dark',
#   'dark',
#   'former',
#   'former',
#   'little',
#   'new',
#   'much',
#   'laundry',
#   'dark',
#   'kyle',
#   'strange',
#   'aware',
#   'closer',
#   'weird'],
#  ['young',
#   'senior',
#   'high',
#   'small',
#   'alive',
#   'sing',
#   'young',
#   'first',
#   'uninterested',
#   'sing',
#   'traditional',
#   'dominic',
#   'local',
#   'first',
#   'hesitant',
#   'ex',
#   'dominic',
#   'uniting',
#   'enough',
#   'upcoming',
#   'informed',
#   'recent',
#   'great',
#   'senior',
#   'main',
#   'unconscious',
#   'dominic'],
#  ['fictional',
#   'fictional',
#   'fake',
#   'equal',
#   'original',
#   'former',
#   'injured',
#   'new',
#   'plush',
#   'extended',
#   'whole',
#   'brought',
#   'local',
#   'grassroots',
#   'simple',
#   'altruistic',
#   'new',
#   'first',
#   'nationwide',
#   'prepared',
#   'original',
#   'historical'],
#  ['short', 'usual', 'invisible', 'invisible'],
#  ['best',
#   'secret',
#   'married',
#   'antique',
#   'mean',
#   'secret',
#   'angry',
#   'previous',
#   'selfish',
#   'happy'],
#  ['illegal', 'responsible', 'illegal', 'barren', 'inoperable', 'complicated'],
#  ['onetime'],
#  ['american',
#   'british',
#   'jewish',
#   'british',
#   'second',
#   'jewish',
#   'illegal',
#   'military',
#   'british',
#   'british',
#   'safe',
#   'young',
#   'young',
#   'new',
#   'young',
#   'radical',
#   'mainstream',
#   'jewish',
#   'diplomatic',
#   'british',
#   'ill',
#   'fictional',
#   'jewish',
#   'actual',
#   'present',
#   'lebanese',
#   'historical',
#   'british',
#   'lifelong',
#   'independent',
#   'prior',
#   'younger',
#   'overnight',
#   'ecstatic',
#   'new',
#   'following',
#   'jewish'],
#  ['local',
#   'willing',
#   'new',
#   'white',
#   'strong',
#   'minded',
#   'strong',
#   'beautiful',
#   'older',
#   'safe',
#   'main',
#   'small',
#   'denied',
#   'several',
#   'ends',
#   'worse',
#   'new',
#   'angry',
#   'possible',
#   'personal',
#   'ta',
#   'free',
#   'close',
#   'enough',
#   'full',
#   'hot',
#   'chase',
#   'whole',
#   'reluctant',
#   'old',
#   'first'],
#  ['sexual', 'remote', 'evil', 'biggest'],
#  ['valuable', 'longstanding'],
#  ['favorite', 'favorite', 'little', 'high', 'high', 'popular', 'true'],
#  ['surreal',
#   'young',
#   'wealthy',
#   'whole',
#   'early',
#   'opening',
#   'latest',
#   'italian',
#   'financial',
#   'best',
#   'secret',
#   'sexual',
#   'exclusive',
#   'beautiful',
#   'similar',
#   'former',
#   'possessive',
#   'italian',
#   'dead',
#   'main',
#   'sadistic',
#   'younger',
#   'financial',
#   'ensuing',
#   'fictional'],
#  ['young',
#   'unfamiliar',
#   'silent',
#   'general',
#   'former',
#   'unhappily',
#   'married',
#   'second'],
#  ['early', 'italian', 'comic', 'several', 'subsequent'],
#  ['lonely',
#   'red',
#   'clown',
#   'scattered',
#   'underneath',
#   'confused',
#   'second',
#   'green',
#   'red',
#   'uproarous',
#   'short'],
#  ['sexual'],
#  ['several', 'opposite'],
#  ['composite',
#   'slave',
#   'existed',
#   'petty',
#   'white',
#   'dead',
#   'sexual',
#   'overwhelming',
#   'social',
#   'successive',
#   'black',
#   'native',
#   'treacherous',
#   'unwritten',
#   'black',
#   'white',
#   'contradictory',
#   'severe',
#   'defenseless',
#   'capricious',
#   'white',
#   'black'],
#  ['best', 'minor', 'responsible', 'best'],
#  ['new',
#   'big',
#   'honourable',
#   'young',
#   'orphaned',
#   'former',
#   'evil',
#   'orphaned',
#   'innocent',
#   'young',
#   'personal',
#   'former',
#   'safe',
#   'happy',
#   'whole',
#   'good',
#   'naïve',
#   'young',
#   'new',
#   'big',
#   'gang',
#   'simple',
#   'protective',
#   'good',
#   'young',
#   'beautiful',
#   'young',
#   'young',
#   'wounded',
#   'initial',
#   'new',
#   'undercover',
#   'real',
#   'secret',
#   'bliss',
#   'learn',
#   'aware',
#   'public',
#   'young',
#   'possible',
#   'ecstatic',
#   'evil',
#   'whole',
#   'late',
#   'local',
#   'true',
#   'little',
#   'entire',
#   'whole',
#   'real',
#   'little',
#   'earliest',
#   'little',
#   'upcoming',
#   'interested',
#   'big',
#   'last',
#   'young',
#   'little',
#   'failing',
#   'unable',
#   'legs',
#   'lest',
#   'ritual',
#   'essential',
#   'last',
#   'overwhelms',
#   'poor',
#   'last',
#   'horrible',
#   'last',
#   'hidden',
#   'red',
#   'injured'],
#  ['identical',
#   'single',
#   'trouble',
#   'local',
#   'unmarried',
#   'unsuspecting',
#   'married'],
#  ['egotistical',
#   'enough',
#   'proud',
#   'lovely',
#   'overprotective',
#   'professional'],
#  ['favorite',
#   'westernized',
#   'suspicious',
#   'traditional',
#   'traditional',
#   'indian',
#   'false'],
#  ['known',
#   'heavy',
#   'high',
#   'general',
#   'deep',
#   'public',
#   'main',
#   'alive',
#   'rubble',
#   'closest'],
#  [],
#  ['lonely', 'poor', 'poor', 'good', 'stolen', 'social'],
#  ['worst',
#   'crowded',
#   'high',
#   'frantic',
#   'unsuccessful',
#   'sustained',
#   'nervous',
#   'unable',
#   'high',
#   'unstable',
#   'high',
#   'attempted',
#   'painful',
#   'best',
#   'safe',
#   'real',
#   'first'],
#  ['old',
#   'arrive',
#   'front',
#   'bloody',
#   'nanny',
#   'black',
#   'red',
#   'giant',
#   'giant',
#   'psychopathic',
#   'real',
#   'psychotic',
#   'first',
#   'fourth',
#   'last',
#   'upper',
#   'alive'],
#  ['tent',
#   'virtual',
#   'flimsy',
#   'hostile',
#   'unable',
#   'difficult',
#   'worst',
#   'confront',
#   'general',
#   'local'],
#  ['main',
#   'friendship',
#   'bitter',
#   'idle',
#   'continuous',
#   'adult',
#   'impoverished',
#   'high',
#   'unceasing',
#   'communal',
#   'main',
#   'ideal',
#   'renowned',
#   'mismanaged',
#   'psychological',
#   'elaborate',
#   'fake',
#   'last',
#   'much',
#   'funeral',
#   'dead'],
#  ['complete',
#   'various',
#   'usual',
#   'frenetic',
#   'various',
#   'small',
#   'strong',
#   'high'],
#  ['young', 'various', 'social', 'enigmatic', 'young', 'dramatic'],
#  ['big', 'real'],
#  ['factual',
#   'worldly',
#   'historical',
#   'southern',
#   'reluctant',
#   'sworn',
#   'entrapped',
#   'infant',
#   'diplomatic',
#   'subsequent',
#   'advancing',
#   'light',
#   'main',
#   'main',
#   'miniaturised',
#   'allied',
#   'unsuspecting',
#   'disheartened',
#   'new',
#   'red',
#   'right',
#   'military',
#   'ingenious',
#   'respective',
#   'earlier',
#   'folly',
#   'late',
#   'special',
#   'climatic',
#   'southeast',
#   'ambitious',
#   'entire',
#   'offensive',
#   'testudo',
#   'heavy',
#   'main',
#   'western',
#   'title',
#   'opening',
#   'historical',
#   'asian',
#   'notable',
#   'early',
#   'western',
#   'original'],
#  ['japanese',
#   'thief',
#   'japanese',
#   'manchurian',
#   'various',
#   'good',
#   'third',
#   'manchurian',
#   'escalating',
#   'japanese',
#   'japanese',
#   'graphic',
#   'manchurian',
#   'japanese',
#   'good',
#   'japanese',
#   'good',
#   'prolonged',
#   'useless',
#   'crude',
#   'good',
#   'new'],
#  ['old',
#   'russian',
#   'ukrainian',
#   'former',
#   'urges',
#   'unstable',
#   'former',
#   'impressed',
#   'full',
#   'appropriate',
#   'incompetent',
#   'severe',
#   'british',
#   'senior',
#   'undercover',
#   'statutory',
#   'safe',
#   'unable',
#   'little',
#   'last'],
#  ['sign', 'animal'],
#  ['old', 'beautiful', 'strange', 'difficult', 'future', 'unexpected', 'funny'],
#  ['opposite', 'trusting', 'several', 'numerous', 'various'],
#  ['older',
#   'financial',
#   'local',
#   'unpaid',
#   'various',
#   'old',
#   'old',
#   'sufficient',
#   'right',
#   'terrorist'],
#  ['opposite', 'christian', 'sentimental', 'young', 'impending'],
#  ['senior', 'foppish', 'british', 'receptive'],
#  ['evil',
#   'young',
#   'good',
#   'respective',
#   'skilled',
#   'destroy',
#   'unhappy',
#   'helpful',
#   'evil'],
#  ['old', 'institutionalized', 'mental'],
#  ['worst', 'strict', 'single', 'full', 'owed'],
#  ['serial', 'unanimous', 'dead', 'public', 'detective'],
#  ['wealthy'],
#  ['old',
#   'nymphomaniac',
#   'amnesiac',
#   'fortune',
#   'least',
#   'oral',
#   'drunken',
#   'present',
#   'young',
#   'prosthetic',
#   'tragic',
#   'allergic',
#   'various',
#   'melodramatic',
#   'cello',
#   'first',
#   'tragic',
#   'dead',
#   'plaintive',
#   'jagged',
#   'enough',
#   'legs',
#   'tragic',
#   'giant',
#   'shattered',
#   'spilled',
#   'entire'],
#  ['slum'],
#  ['similar',
#   'present',
#   'poor',
#   'beautiful',
#   'young',
#   'unforgiving',
#   'young',
#   'young',
#   'films'],
#  ['former',
#   'socialite',
#   'couple',
#   'pen',
#   'unhappy',
#   'german',
#   'british',
#   'american',
#   'maximum',
#   'rendezvous',
#   'new',
#   'german',
#   'valuable',
#   'supposedly',
#   'unbreakable',
#   'dead',
#   'funeral',
#   'free',
#   'russian',
#   'german',
#   'new',
#   'american',
#   'new',
#   'rendezvous'],
#  ['unexplainable',
#   'phenomena',
#   'mysterious',
#   'first',
#   'mysterious',
#   'whole',
#   'short',
#   'utilizes',
#   'otherworldly',
#   'wide',
#   'small'],
#  ['beautiful',
#   'black',
#   'abandoned',
#   'shot',
#   'nice',
#   'outside',
#   'abandoned',
#   'real',
#   'young',
#   'outside',
#   'abandoned',
#   'trio',
#   'english',
#   'free',
#   'entire',
#   'jamal',
#   'oral',
#   'good',
#   'evil'],
#  ['palpable',
#   'old',
#   'tiny',
#   'unmoored',
#   'strong',
#   'first',
#   'long',
#   'good',
#   'right',
#   'best',
#   'metaphysical',
#   'angry',
#   'long',
#   'long',
#   'alive',
#   'best',
#   'divorced',
#   'right',
#   'dead',
#   'new'],
#  ['unhappy', 'respective', 'everyday', 'intimate', 'unassuming'],
#  ['love', 'married', 'dead', 'late'],
#  ['usual',
#   'sheepishly',
#   'inexorable',
#   'opposite',
#   'best',
#   'narrow',
#   'opposite',
#   'first',
#   'empty',
#   'safe',
#   'chest',
#   'safe',
#   'fourth',
#   'safe',
#   'second',
#   'fifth',
#   'dazed',
#   'unhurt',
#   'third',
#   'unable',
#   'sixth',
#   'actual',
#   'unhappy',
#   'yellow',
#   'new',
#   'explosive',
#   'first',
#   'little',
#   'agitated',
#   'original',
#   'cheap',
#   'whole',
#   'full',
#   'normal',
#   'small',
#   'ecstatic',
#   'tall',
#   'amplified'],
#  ['previous',
#   'great',
#   'white',
#   'older',
#   'carefree',
#   'marine',
#   'strange',
#   'unexplained',
#   'tracking',
#   'unharmed',
#   'inflatable',
#   'explosive',
#   'electrical',
#   'absent',
#   'broken',
#   'injured',
#   'alive'],
#  ['big',
#   'unable',
#   'best',
#   'best',
#   'powerful',
#   'considerable',
#   'favourite',
#   'current',
#   'repeated',
#   'responsible',
#   'dead'],
#  ['uplifting',
#   'warm',
#   'crippling',
#   'great',
#   'paraplegic',
#   'little',
#   'rich',
#   'good',
#   'original',
#   'warm',
#   'true'],
#  ['personal', 'insecure', 'best'],
#  ['older',
#   'several',
#   'authorized',
#   'private',
#   'temporary',
#   'military',
#   'older',
#   'impressed',
#   'israeli'],
#  ['high',
#   'steady',
#   'great',
#   'main',
#   'carefree',
#   'positive',
#   'heavy',
#   'rapid',
#   'swab',
#   'positive',
#   'young',
#   'secret',
#   'high'],
#  ['mexican',
#   'high',
#   'third',
#   'black',
#   'dark',
#   'major',
#   'bloody',
#   'glowing',
#   'demon',
#   'first',
#   'second',
#   'unable',
#   'magical',
#   'magical',
#   'black'],
#  ['speak', 'french', 'personal', 'various'],
#  ['actuary',
#   'new',
#   'foster',
#   'small',
#   'tanzanian',
#   'candid',
#   'young',
#   'declined',
#   'entire',
#   'longtime',
#   'arrive',
#   'funeral',
#   'cheap',
#   'waterbed',
#   'hidden',
#   'mutual',
#   'new',
#   'clear',
#   'right',
#   'late',
#   'full',
#   'hot',
#   'dead',
#   'illiterate',
#   'financial',
#   'large',
#   'small',
#   'sunny'],
#  ['difficult', 'nervous', 'young'],
#  ['ambitious',
#   'idealistic',
#   'remote',
#   'rural',
#   'secure',
#   'unwilling',
#   'backward',
#   'first',
#   'acquainted',
#   'long',
#   'old',
#   'new',
#   'isolated',
#   'reluctant',
#   'first',
#   'agonized',
#   'dead',
#   'temporary',
#   'large',
#   'good',
#   'contemptuous',
#   'prolonged',
#   'best',
#   'safe',
#   'chinese',
#   'good',
#   'shot',
#   'new',
#   'new',
#   'old',
#   'menial'],
#  ['biggest',
#   'relative',
#   'worse',
#   'worse',
#   'small',
#   'following',
#   'dried',
#   'necessary',
#   'necessary',
#   'combined',
#   'small',
#   'following',
#   'dry',
#   'following',
#   'herbivorous',
#   'elemental',
#   'enough',
#   'last',
#   'verdant'],
#  ['young',
#   'best',
#   'fifth',
#   'birthday',
#   'unable',
#   'entire',
#   'wish',
#   'true',
#   'unable',
#   'true',
#   'inconvenient',
#   'main',
#   'willing',
#   'desired',
#   'new',
#   'prenuptial',
#   'minor',
#   'invalid',
#   'responsible',
#   'earlier',
#   'noble',
#   'senior',
#   'highest',
#   'normal'],
#  ['young',
#   'married',
#   'antebellum',
#   'bloodied',
#   'wealthy',
#   'guilty',
#   'new',
#   'poor',
#   'local',
#   'mysterious',
#   'disembodied',
#   'interested',
#   'drugged',
#   'dead',
#   'mad',
#   'crazy',
#   'previous',
#   'last'],
#  ['spanish'],
#  ['lead', 'former'],
#  ['french', 'young', 'rich', 'dramatic'],
#  ['entire',
#   'actual',
#   'several',
#   'new',
#   'musical',
#   'greatest',
#   'dramatic',
#   'worthy',
#   'ritual',
#   'primitive',
#   'black',
#   'american',
#   'rhythmic',
#   'religious',
#   'suggestive',
#   'copious',
#   'original',
#   'present',
#   'subsequent',
#   'american',
#   'first',
#   'military',
#   'big',
#   'fast',
#   'boisterous',
#   'beautiful',
#   'first',
#   'unusual',
#   'black',
#   'sexual',
#   'cultural',
#   'libidinal',
#   'black',
#   'white',
#   'remote',
#   'black',
#   'dilapidated',
#   'white',
#   'poor'],
#  ['secret', 'second', 'first', 'clear', 'small', 'actual', 'short'],
#  ['routine', 'small', 'unable', 'useless', 'desperate', 'several'],
#  ['randy',
#   'high',
#   'senior',
#   'poor',
#   'secret',
#   'married',
#   'first',
#   'difficult',
#   'cliquish',
#   'angry',
#   'new',
#   'small',
#   'front',
#   'first',
#   'local',
#   'intolerant',
#   'closest',
#   'hostile',
#   'least',
#   'choose',
#   'high',
#   'accusatory',
#   'past',
#   'top',
#   'aware'],
#  ['unwilling', 'pen', 'entire'],
#  ['pierre',
#   'young',
#   'stricken',
#   'young',
#   'unloving',
#   'locked',
#   'secret',
#   'young',
#   'earlier',
#   'former',
#   'dead'],
#  ['japanese',
#   'masked',
#   'remote',
#   'local',
#   'several',
#   'superior',
#   'japanese',
#   'japanese',
#   'climactic'],
#  ['angry',
#   'snatched',
#   'become',
#   'wish',
#   'wish',
#   'married',
#   'meanwhile',
#   'confused',
#   'second',
#   'neighbour',
#   'vacate',
#   'official',
#   'long'],
#  ['steadfast', 'false'],
#  ['best',
#   'best',
#   'main',
#   'first',
#   'special',
#   'old',
#   'rigorous',
#   'drastic',
#   'personal',
#   'innocent',
#   'vivacious',
#   'rich',
#   'shattered',
#   'whereas',
#   'interesting',
#   'several',
#   'powerful'],
#  ['severe', 'detective', 'private'],
#  ['full',
#   'poor',
#   'protective',
#   'exclusive',
#   'secret',
#   'unannounced',
#   'younger',
#   'feelings',
#   'call'],
#  ['first',
#   'normal',
#   'unable',
#   'previous',
#   'unborn',
#   'legendary',
#   'magical',
#   'main',
#   'numerous',
#   'military',
#   'great',
#   'initial',
#   'central',
#   'asian',
#   'resentful',
#   'large',
#   'angry',
#   'direct',
#   'real',
#   'unable',
#   'dead',
#   'panicked',
#   'enraged',
#   'last',
#   'fourteen',
#   'entire',
#   'normal',
#   'undemolished',
#   'first',
#   'unborn',
#   'accurate',
#   'first'],
#  ['married',
#   'german',
#   'unfaithful',
#   'pharmaceutical',
#   'groundbreaking',
#   'ill',
#   'expensive',
#   'ample',
#   'small',
#   'southern'],
#  ['small',
#   'recent',
#   'old',
#   'porn',
#   'best',
#   'innocuous',
#   'mashed',
#   'narrow',
#   'tenuous',
#   'impressive',
#   'crafts',
#   'tiny',
#   'pink',
#   'outright',
#   'exemplary',
#   'fashionable',
#   'confident',
#   'uncomfortable',
#   'prior',
#   'unscathed'],
#  ['firebrand',
#   'opposite',
#   'rich',
#   'best',
#   'departed',
#   'unmarried',
#   'dancing',
#   'suicide',
#   'suicide'],
#  ['young',
#   'lovely',
#   'unlucky',
#   'unable',
#   'unsuccessful',
#   'alcoholic',
#   'best',
#   'military',
#   'meant',
#   'determined',
#   'mere',
#   'library'],
#  ['demonic',
#   'dark',
#   'satanic',
#   'japanese',
#   'first',
#   'small',
#   'little',
#   'christian',
#   'small',
#   'long',
#   'light',
#   'mere',
#   'recent',
#   'recent',
#   'black',
#   'new',
#   'narrow',
#   'aerial',
#   'intense',
#   'old',
#   'decapitated',
#   'ballistic',
#   'black',
#   'christian',
#   'useless',
#   'ninjas',
#   'free',
#   'biggest',
#   'strongest',
#   'tactical',
#   'little',
#   'tall',
#   'folding',
#   'small',
#   'alive',
#   'main',
#   'tall',
#   'second',
#   'younger',
#   'stronger',
#   'historical',
#   'strongest',
#   'swordmanship',
#   'legendary',
#   'several',
#   'old',
#   'old',
#   'much',
#   'old',
#   'servant',
#   'arrive',
#   'young',
#   'beautiful',
#   'last',
#   'unmarried',
#   'noble',
#   'large',
#   'strange',
#   'standstill',
#   'jushin',
#   'least',
#   'ninjas',
#   'ninjas',
#   'lower',
#   'ninjas',
#   'several',
#   'futile',
#   'shinobi',
#   'dark',
#   'resurrected',
#   'inhuman',
#   'skilled',
#   'useful',
#   'small',
#   'old',
#   'old',
#   'staked',
#   'old',
#   'familiar',
#   'old',
#   'young',
#   'old',
#   'old',
#   'little',
#   'old',
#   'old',
#   'old',
#   'little',
#   'spacious',
#   'large',
#   'gigantic',
#   'numerous',
#   'full',
#   'cloud',
#   'red',
#   'silent',
#   'enormous',
#   'smog',
#   'big',
#   'bulbous',
#   'long',
#   'wooden',
#   'electrical',
#   'long',
#   'naked',
#   'untangle',
#   'green',
#   'normal',
#   'strong'],
#  ['late',
#   'international',
#   'doomed',
#   'illicit',
#   'black',
#   'strong',
#   'indigenous',
#   'white',
#   'supremacist',
#   'rhodesian',
#   'reluctant',
#   'unarmed',
#   'rhodesian',
#   'armed',
#   'unarmed',
#   'foiled',
#   'unable',
#   'active',
#   'armed'],
#  ['detective',
#   'former',
#   'sting',
#   'blunt',
#   'dismissive',
#   'unrepentant',
#   'close',
#   'principal',
#   'brashly',
#   'total',
#   'dogged',
#   'undergoes',
#   'significant'],
#  ['quirky',
#   'pleasant',
#   'innocuous',
#   'uneventful',
#   'seductive',
#   'new',
#   'little',
#   'initial',
#   'allergic',
#   'addictive',
#   'old',
#   'entire',
#   'empty',
#   'empty',
#   'initial',
#   'nearby',
#   'dead',
#   'actor',
#   'jean',
#   'whole',
#   'free',
#   'dead',
#   'free',
#   'dead',
#   'dead',
#   'replete',
#   'replaced',
#   'little',
#   'charred',
#   'torched',
#   'fireproof'],
#  ['wealthiest',
#   'black',
#   'poor',
#   'interested',
#   'deep',
#   'biggest',
#   'wealthiest',
#   'united',
#   'nali'],
#  ['unsuccessful', 'diabetic', 'disastrous', 'second', 'perfect', 'leading'],
#  ['deadly',
#   'antidote',
#   'crepe',
#   'infected',
#   'infected',
#   'stuffed',
#   'bear',
#   'good',
#   'real'],
#  ['american',
#   'japanese',
#   'small',
#   'beautiful',
#   'old',
#   'good',
#   'good',
#   'flirty',
#   'favorite',
#   'orthodox',
#   'long',
#   'close',
#   'unable',
#   'sexual',
#   'impotent',
#   'much',
#   'new',
#   'new',
#   'indifferent',
#   'pure',
#   'first'],
#  ['remote', 'capable', 'first', 'young', 'unusual', 'older'],
#  ['hardened',
#   'cynical',
#   'naïve',
#   'army',
#   'military',
#   'overnight',
#   'following',
#   'isolated',
#   'rather',
#   'signed'],
#  ['first',
#   'apparent',
#   'nervous',
#   'weekly',
#   'american',
#   'similar',
#   'american',
#   'latest',
#   'american',
#   'western',
#   'extended',
#   'american',
#   'terrorist',
#   'suicide',
#   'small',
#   'small',
#   'explosive',
#   'american',
#   'last',
#   'musical',
#   'new',
#   'new',
#   'american'],
#  ['carefree', 'financial', 'rich', 'angry', 'forced', 'best'],
#  ['naive',
#   'sorry',
#   'bible',
#   'yiddish',
#   'french',
#   'unaware',
#   'notorious',
#   'ritual',
#   'large',
#   'golden',
#   'new',
#   'first',
#   'last',
#   'memorable'],
#  ['main', 'decent', 'progressive'],
#  ['apparent', 'hesitant', 'first', 'dead', 'longtime'],
#  ['suspicious', 'alive'],
#  ['short',
#   'present',
#   'insulted',
#   'windy',
#   'ukulele',
#   'double',
#   'third',
#   'major',
#   'big',
#   'large',
#   'first',
#   'ta',
#   'hot',
#   'real'],
#  ['french',
#   'future',
#   'small',
#   'hereditary',
#   'first',
#   'first',
#   'french',
#   'personal'],
#  [],
#  ['innocent',
#   'young',
#   'accurate',
#   'local',
#   'real',
#   'several',
#   'bitter',
#   'educational',
#   'last',
#   'sweet',
#   'last'],
#  ['british', 'private', 'italian', 'second', 'great'],
#  ['individual',
#   'desperate',
#   'rich',
#   'former',
#   'suicide',
#   'old',
#   'safe',
#   'personal',
#   'short'],
#  ['conspiratorial',
#   'bawdy',
#   'feared',
#   'first',
#   'official',
#   'humanitarian',
#   'minor',
#   'real',
#   'fair',
#   'chief',
#   'real',
#   'fake'],
#  ['big'],
#  ['private', 'possible', 'wealthy', 'ulterior'],
#  ['first'],
#  ['major',
#   'strange',
#   'mysterious',
#   'sphere',
#   'dead',
#   'alive',
#   'strange',
#   'early',
#   'entire',
#   'useless',
#   'giant',
#   'magical',
#   'tree',
#   'small',
#   'vial',
#   'lost',
#   'tree',
#   'strange',
#   'large',
#   'tree',
#   'secret',
#   'safe',
#   'strange',
#   'tree',
#   'similar',
#   'stumble',
#   'mysterious',
#   'royal',
#   'strange',
#   'tree',
#   'astral',
#   'greatest',
#   'several',
#   'dead',
#   'new',
#   'loose',
#   'secret',
#   'new',
#   'tree',
#   'angry',
#   'astral',
#   'fob',
#   'giant',
#   'unconscious'],
#  ['rich', 'former', 'wealthy', 'poor'],
#  ['angry', 'undaunted', 'cinematic', 'entertaining'],
#  ['big',
#   'possible',
#   'young',
#   'automotive',
#   'outside',
#   'real',
#   'real',
#   'guilty',
#   'old',
#   'full',
#   'real',
#   'responsible',
#   'square',
#   'free'],
#  ['local', 'lakeside', 'lethal', 'large', 'eccentric', 'local'],
#  ['young',
#   'devastated',
#   'local',
#   'recent',
#   'real',
#   'notorious',
#   'idiotic',
#   'sebastian',
#   'sebastian',
#   'sebastian',
#   'latter',
#   'real',
#   'humiliated',
#   'high'],
#  ['deep',
#   'supposedly',
#   'old',
#   'marine',
#   'unmanned',
#   'small',
#   'mysterious',
#   'nearby',
#   'functional',
#   'green',
#   'dead',
#   'shockwave',
#   'external',
#   'reptilian',
#   'higher',
#   'flooded',
#   'unstable',
#   'erratic',
#   'dead',
#   'complete',
#   'explodes',
#   'rapid',
#   'mcbride',
#   'complete',
#   'strong',
#   'finish',
#   'dead'],
#  ['suburban',
#   'sexual',
#   'part',
#   'lonely',
#   'part',
#   'indefatigable',
#   'part',
#   'secluded'],
#  ['appalachian',
#   'young',
#   'young',
#   'sheriff',
#   'tabloid',
#   'sheriff',
#   'dead',
#   'arrive',
#   'big',
#   'empty',
#   'former',
#   'sheriff',
#   'outside',
#   'sheriff',
#   'sheriff',
#   'alive'],
#  ['grateful',
#   'great',
#   'private',
#   'older',
#   'unhappy',
#   'unhappy',
#   'young',
#   'loved',
#   'severe',
#   'unable',
#   'medical',
#   'illegitimate',
#   'new',
#   'bitter',
#   'angry',
#   'emotional'],
#  ['frequent',
#   'shrewd',
#   'tamed',
#   'nondescript',
#   'unrideable',
#   'rather',
#   'bright',
#   'much',
#   'nearest',
#   'veterinary',
#   'new'],
#  ['young', 'russian', 'rich', 'russian'],
#  ['involved', 'billionarie'],
#  [],
#  ['closest', 'fey', 'right'],
#  ['financial',
#   'first',
#   'smuggled',
#   'eligible',
#   'several',
#   'repeated',
#   'burnt',
#   'real',
#   'real',
#   'actual',
#   'real',
#   'unwilling',
#   'real',
#   'negative',
#   'real'],
#  ['popular',
#   'embittered',
#   'younger',
#   'financial',
#   'great',
#   'real',
#   'strange',
#   'lab',
#   'vial',
#   'new',
#   'blue',
#   'wolf',
#   'paranormal',
#   'expert',
#   'old',
#   'ancient',
#   'graceful',
#   'athletic',
#   'dark',
#   'new',
#   'young',
#   'first',
#   'aware',
#   'normal',
#   'late',
#   'full',
#   'entire',
#   'silver',
#   'cursed',
#   'brilliant',
#   'humanitarian',
#   'evil',
#   'sacred',
#   'dead',
#   'new',
#   'evil',
#   'silver',
#   'full',
#   'aware',
#   'permanent',
#   'confident',
#   'new',
#   'latest',
#   'injured'],
#  ['present', 'resultant', 'several', 'young', 'present', 'reddish'],
#  ['similar',
#   'colleague',
#   'small',
#   'exact',
#   'much',
#   'devastating',
#   'lifelong',
#   'experiment',
#   'titular',
#   'deformed',
#   'ex',
#   'short',
#   'anxious',
#   'complete',
#   'red',
#   'entire',
#   'unstoppable',
#   'smaller',
#   'complete',
#   'undergoes',
#   'last',
#   'alive',
#   'electrical',
#   'gillian',
#   'altered'],
#  ['small',
#   'local',
#   'temporary',
#   'happy',
#   'beautiful',
#   'young',
#   'shy',
#   'particular',
#   'suitable',
#   'strong',
#   'sensual',
#   'best',
#   'christian',
#   'several',
#   'old',
#   'old',
#   'beautiful',
#   'several',
#   'old',
#   'large'],
#  ['contemporary',
#   'local',
#   'second',
#   'traditional',
#   'traditional',
#   'young',
#   'previous'],
#  ['perfect', 'perfect', 'secluded', 'innocent', 'real', 'last', 'alive'],
#  ['painful',
#   'beautiful',
#   'rican',
#   'idyllic',
#   'personal',
#   'closer',
#   'unexpected',
#   'past',
#   'tentative',
#   'new'],
#  ['last', 'psychotic', 'mental'],
#  ['financial', 'petty', 'european', 'wealthy'],
#  ['passionate',
#   'passionate',
#   'graphic',
#   'translucent',
#   'plastic',
#   'last',
#   'actual',
#   'nasty',
#   'novel',
#   'true',
#   'menial',
#   'inspired',
#   'best',
#   'intimate',
#   'worse',
#   'overwhelmed',
#   'funeral',
#   'new',
#   'local',
#   'white',
#   'smooth',
#   'emotional',
#   'positive',
#   'medical',
#   'negative',
#   'emotional',
#   'distraught',
#   'emotional',
#   'mental',
#   'unresponsive',
#   'unaware',
#   'ear',
#   'happy',
#   'small',
#   'free',
#   'spirited',
#   'comic',
#   'tragic'],
#  ['big', 'financial', 'safe'],
#  ['lurid', 'wealthy', 'enigmatic'],
#  ['last', 'neurotic', 'child'],
#  ['remote', 'american', 'swedish', 'interested', 'local', 'fish', 'mere'],
#  ['successive',
#   'light',
#   'humorous',
#   'intense',
#   'best',
#   'good',
#   'present',
#   'past',
#   'future',
#   'smooth',
#   'love',
#   'senior',
#   'familiar',
#   'married',
#   'habitual',
#   'single',
#   'fastidious',
#   'strangely',
#   'stern',
#   'old',
#   'difficult',
#   'old',
#   'happy',
#   'whole',
#   'gloomy',
#   'opposite',
#   'terrific',
#   'main',
#   'maximum',
#   'good',
#   'remarkable',
#   'dead',
#   'grand',
#   'mythological',
#   'short',
#   'first',
#   'old',
#   'acceptable',
#   'entire',
#   'new',
#   'devoid',
#   'least',
#   'old',
#   'obsolete',
#   'good',
#   'younger',
#   'good',
#   'acting',
#   'acting',
#   'young',
#   'noticeable',
#   'good',
#   'meaningful',
#   'nahin',
#   'possible',
#   'beautiful',
#   'eligible',
#   'true',
#   'emotional',
#   'effectiveness',
#   'old',
#   'good'],
#  ['elderly',
#   'undue',
#   'negative',
#   'weak',
#   'coherent',
#   'personal',
#   'large',
#   'suburban',
#   'ill',
#   'safe',
#   'cardiac',
#   'alive',
#   'dark',
#   'dead',
#   'undead',
#   'vengeful',
#   'free',
#   'hypnotic',
#   'undead',
#   'dead',
#   'free',
#   'late',
#   'dead',
#   'safe',
#   'hypnotic',
#   'hypnotic',
#   'digital',
#   'large',
#   'dead',
#   'several',
#   'strange',
#   'stolen',
#   'dismantled',
#   'naked',
#   'professional',
#   'local',
#   'mysterious',
#   'black',
#   'delicate',
#   'ethereal',
#   'gritty',
#   'professional',
#   'private',
#   'local',
#   'high',
#   'local',
#   'several',
#   'strong',
#   'mysterious',
#   'excessive',
#   'newest',
#   'lurid',
#   'revolting',
#   'strangled',
#   'local',
#   'black',
#   'identical',
#   'identical',
#   'white',
#   'suspicious',
#   'confident',
#   'elaborate',
#   'black',
#   'stern',
#   'fake',
#   'troublesome',
#   'front',
#   'second',
#   'black'],
#  ['young',
#   'large',
#   'indentured',
#   'fleeting',
#   'younger',
#   'french',
#   'sixteen',
#   'french',
#   'past',
#   'dead',
#   'unconscious',
#   'loud',
#   'remote',
#   'french',
#   'military',
#   'notorious',
#   'engaged',
#   'young',
#   'french',
#   'traveling',
#   'dead',
#   'french',
#   'hidden',
#   'large',
#   'french',
#   'former',
#   'french',
#   'certain',
#   'northern',
#   'chinese',
#   'french',
#   'étienne',
#   'french',
#   'spends',
#   'étienne',
#   'shot',
#   'dead',
#   'safe',
#   'french',
#   'independent'],
#  ['young',
#   'desperate',
#   'ambiguous',
#   'previous',
#   'prepared',
#   'dedicated',
#   'lukewarm',
#   'best',
#   'lax',
#   'new'],
#  ['lifelong', 'various', 'frustrated', 'hot'],
#  ['various', 'indian', 'numerous', 'abandoned'],
#  ['tiny',
#   'imaginative',
#   'tiny',
#   'entire',
#   'atop',
#   'safest',
#   'identical',
#   'beezelnut',
#   'boiling',
#   'last',
#   'highest',
#   'pouch',
#   'right',
#   'numerous'],
#  ['long', 'new'],
#  ['uncovered', 'frantic'],
#  ['unable',
#   'receive',
#   'new',
#   'young',
#   'black',
#   'normal',
#   'suspicious',
#   'cynical',
#   'first',
#   'free',
#   'good',
#   'false'],
#  ['local'],
#  ['heartless', 'strange'],
#  ['good',
#   'irresponsible',
#   'good',
#   'illegal',
#   'broken',
#   'happy',
#   'first',
#   'unsuccessful',
#   'first',
#   'unsuccessful',
#   'much',
#   'willing',
#   'last',
#   'missing',
#   'worth'],
#  ['single',
#   'eternal',
#   'redemptive',
#   'tactful',
#   'new',
#   'ethical',
#   'developmental'],
#  ['detective',
#   'tough',
#   'small',
#   'alaskan',
#   'responsible',
#   'immediate',
#   'young',
#   'clear',
#   'mad',
#   'reluctant',
#   'several',
#   'upsets',
#   'new'],
#  ['happy'],
#  ['larger',
#   'blue',
#   'red',
#   'longer',
#   'high',
#   'technological',
#   'spiritual',
#   'enormous',
#   'apparent',
#   'child',
#   'master',
#   'great',
#   'collar',
#   'several',
#   'dark',
#   'tiny',
#   'indoor',
#   'small',
#   'certain',
#   'stationary',
#   'several',
#   'ritual',
#   'respective',
#   'sufficient',
#   'acceptable',
#   'structured',
#   'walled',
#   'willing',
#   'several',
#   'useful',
#   'occasional',
#   'evil',
#   'new',
#   'old',
#   'old',
#   'great',
#   'sizable',
#   'old',
#   'safe',
#   'higher',
#   'new',
#   'old',
#   'old',
#   'abandoned',
#   'mechanized',
#   'old',
#   'updated',
#   'persistent',
#   'lethal',
#   'diverse',
#   'effective',
#   'manned',
#   'meditative',
#   'outstretched',
#   'silly',
#   'headset',
#   'new',
#   'ancestral'],
#  [],
#  ['tribal', 'several', 'ambiguous', 'dead', 'alive', 'several', 'apparent'],
#  [],
#  ['promising',
#   'blind',
#   'acute',
#   'detective',
#   'detective',
#   'imported',
#   'mysterious',
#   'mysterious',
#   'strong',
#   'right',
#   'iced',
#   'dead',
#   'angry',
#   'dead',
#   'upcoming',
#   'first',
#   'thick',
#   'small',
#   'urgently',
#   'safe',
#   'video',
#   'past',
#   'raspy',
#   'licensed',
#   'black',
#   'dead',
#   'various',
#   'past',
#   'right',
#   'unconsious',
#   'similar',
#   'first',
#   'funeral'],
#  ['good',
#   'subsequent',
#   'several',
#   'financial',
#   'expensive',
#   'manual',
#   'south',
#   'sunken',
#   'spanish',
#   'larger',
#   'trustworthy',
#   'real',
#   'new',
#   'wary',
#   'underway',
#   'belligerent',
#   'entire',
#   'unlocked',
#   'safe',
#   'high',
#   'ryan',
#   'ritual',
#   'ritual',
#   'entire',
#   'ryan',
#   'key',
#   'ryan',
#   'fight'],
#  ['first', 'last', 'second', 'third'],
#  ['black',
#   'best',
#   'new',
#   'wealthy',
#   'white',
#   'best',
#   'black',
#   'dead',
#   'several',
#   'guilty',
#   'dead',
#   'negative',
#   'innocent',
#   'reliable'],
#  ['old',
#   'worried',
#   'professional',
#   'unable',
#   'recent',
#   'elaborate',
#   'old',
#   'innocuous',
#   'suspicious',
#   'second',
#   'light',
#   'innocent',
#   'particular',
#   'dark',
#   'desperate',
#   'light',
#   'unnoticed',
#   'large',
#   'ambiguous',
#   'stabs',
#   'unable',
#   'chained',
#   'free',
#   'last',
#   'unbroken',
#   'unplugged',
#   'alive'],
#  ['former', 'military', 'unfaithful', 'strongest', 'dead'],
#  ['french',
#   'close',
#   'adopted',
#   'outside',
#   'virginal',
#   'lavish',
#   'big',
#   'kept',
#   'unable',
#   'distressed',
#   'shelter',
#   'public',
#   'radical',
#   'upstairs',
#   'panicked',
#   'unite',
#   'republic'],
#  ['remote',
#   'captured',
#   'safe',
#   'overpower',
#   'agent',
#   'local',
#   'personal',
#   'following',
#   'closer',
#   'strong',
#   'private',
#   'international',
#   'terrorist',
#   'antiques',
#   'present',
#   'antique',
#   'real',
#   'ransacked',
#   'dead',
#   'rendezvous',
#   'rigged',
#   'indian',
#   'old',
#   'shot',
#   'indian',
#   'possible',
#   'gunshot',
#   'suicide',
#   'great',
#   'beautiful',
#   'russian',
#   'apparent'],
#  ['musical', 'memorable'],
#  ['first',
#   'extreme',
#   'unexpected',
#   'carefree',
#   'freedom',
#   'young',
#   'content',
#   'obvious',
#   'worse',
#   'third',
#   'inner',
#   'new',
#   'worse'],
#  ['young'],
#  ['three',
#   'free',
#   'last',
#   'local',
#   'nearby',
#   'indian',
#   'expensive',
#   'real',
#   'big',
#   'pretty',
#   'pretty',
#   'mysterious',
#   'first',
#   'willing',
#   'southern',
#   'pink',
#   'russian',
#   'main',
#   'stumble',
#   'nearest',
#   'best',
#   'complete',
#   'tearful',
#   'tearful'],
#  ['illegal',
#   'unable',
#   'local',
#   'russian',
#   'indian',
#   'big',
#   'powerful',
#   'safe',
#   'unable',
#   'present',
#   'intense',
#   'former'],
#  ['native',
#   'much',
#   'old',
#   'secret',
#   'happy',
#   'free',
#   'mental',
#   'lost',
#   'delectable'],
#  ['isolated',
#   'wealthy',
#   'wealthy',
#   'foppish',
#   'elderly',
#   'fragile',
#   'arrive',
#   'large',
#   'unusual',
#   'mysterious',
#   'serial',
#   'large',
#   'trivial',
#   'substantial',
#   'additional',
#   'masked',
#   'patient',
#   'happy',
#   'attic',
#   'confrontational',
#   'insane',
#   'guilty',
#   'real',
#   'dead',
#   'lunatic',
#   'false',
#   'happy'],
#  ['unfinished',
#   'ritual',
#   'american',
#   'inhabited',
#   'younger',
#   'daily',
#   'nearby',
#   'mental',
#   'worried',
#   'first',
#   'young',
#   'supernatural',
#   'unstable',
#   'everyday',
#   'new',
#   'supernatural',
#   'ritual',
#   'earlier',
#   'occult',
#   'ritual',
#   'satanic',
#   'ritual',
#   'original',
#   'last',
#   'nervous',
#   'unable',
#   'complete',
#   'real',
#   'fake',
#   'dark'],
#  ['israeli',
#   'israeli',
#   'plausible',
#   'official',
#   'jewish',
#   'south',
#   'former',
#   'shadowy',
#   'french',
#   'first',
#   'dead',
#   'second',
#   'remote',
#   'public',
#   'large',
#   'newlywed',
#   'powerful',
#   'safe',
#   'tense',
#   'squad',
#   'several',
#   'independent',
#   'entire',
#   'dutch',
#   'disillusioned',
#   'new',
#   'last'],
#  ['lethal', 'highest'],
#  ['high',
#   'high',
#   'entire',
#   'last',
#   'high',
#   'first',
#   'first',
#   'high',
#   'new',
#   'new',
#   'beside',
#   'first',
#   'silent',
#   'close',
#   'dance',
#   'mute',
#   'second',
#   'favorite',
#   'bright',
#   'last',
#   'sick',
#   'whole',
#   'early',
#   'favorite'],
#  ['big'],
#  ['younger',
#   'affair',
#   'short',
#   'new',
#   'first',
#   'old',
#   'closer',
#   'long',
#   'distracted',
#   'secret',
#   'anniversary',
#   'much',
#   'rich',
#   'young',
#   'hot',
#   'drunken',
#   'young',
#   'european',
#   'angry',
#   'childish',
#   'last',
#   'excessive',
#   'inevitable',
#   'dead',
#   'suicide',
#   'betty',
#   'fine',
#   'best',
#   'whole',
#   'manipulative',
#   'anniversary',
#   'married',
#   'pleased',
#   'ruined',
#   'married',
#   'failing',
#   'perfect'],
#  ['young',
#   'photo',
#   'convincing',
#   'former',
#   'scary',
#   'longtime',
#   'responsible',
#   'real'],
#  ['threatening', 'former'],
#  ['elderly',
#   'short',
#   'dead',
#   'captured',
#   'short',
#   'frustrated',
#   'veritable',
#   'big',
#   'wittle'],
#  ['interested', 'trick'],
#  ['old', 'key', 'german'],
#  ['unable',
#   'similar',
#   'much',
#   'unhealthy',
#   'following',
#   'sneak',
#   'secret',
#   'big',
#   'healthy',
#   'http',
#   'unveiled',
#   'first',
#   'short',
#   'authentic',
#   'argentinian',
#   'spanish',
#   'spanish',
#   'main',
#   'last',
#   'last',
#   'second',
#   'strange',
#   'fourth',
#   'real',
#   'forgive',
#   'good',
#   'valuable',
#   'fleeting',
#   'parental'],
#  ['local', 'rich'],
#  ['old', 'responsible', 'respectable', 'steady', 'flawless'],
#  ['tense',
#   'snobbish',
#   'irresponsible',
#   'engaged',
#   'best',
#   'diet',
#   'least',
#   'interested',
#   'tough',
#   'best',
#   'entire',
#   'rich',
#   'good'],
#  ['worthless', 'stumble', 'western', 'true', 'great', 'real'],
#  ['young',
#   'coastal',
#   'early',
#   'general',
#   'local',
#   'military',
#   'rehearsal',
#   'official',
#   'lycical',
#   'active',
#   'governmental',
#   'prestigious',
#   'youth'],
#  ['displaced', 'blind'],
#  ['strict',
#   'chronological',
#   'second',
#   'restaurant',
#   'first',
#   'real',
#   'social',
#   'principal',
#   'eldest',
#   'best',
#   'new',
#   'new',
#   'former',
#   'new',
#   'preoccupied',
#   'materialistic',
#   'wealthy',
#   'social',
#   'showdown'],
#  ['first',
#   'real',
#   'old',
#   'responsible',
#   'good',
#   'double',
#   'happy',
#   'first',
#   'complicated',
#   'desperate'],
#  ['shrewish',
#   'older',
#   'hated',
#   'eccentric',
#   'rich',
#   'beautiful',
#   'mysterious',
#   'great',
#   'much',
#   'unpopular',
#   'responsible',
#   'good',
#   'suspicious',
#   'old',
#   'unhappy',
#   'crushed',
#   'alert',
#   'late',
#   'old',
#   'old',
#   'great',
#   'contented',
#   'deserted',
#   'true',
#   'first'],
#  ['near', 'fatal', 'new', 'true'],
#  ['poor', 'guilty'],
#  ['old',
#   'athletic',
#   'small',
#   'peruvian',
#   'several',
#   'free',
#   'funeral',
#   'young',
#   'scramble',
#   'shot',
#   'arrive',
#   'heavy',
#   'inverted',
#   'mothballed'],
#  ['dead', 'unable', 'young'],
#  ['disastrous',
#   'viral',
#   'doctoral',
#   'controversial',
#   'strong',
#   'routine',
#   'cave',
#   'high',
#   'various',
#   'stupid',
#   'telepathic',
#   'telepathic',
#   'evil',
#   'stumble',
#   'recent',
#   'liquid',
#   'favorite',
#   'impressive',
#   'good',
#   'crystal',
#   'triumphant',
#   'new'],
#  ['first',
#   'special',
#   'nature',
#   'light',
#   'silent',
#   'top',
#   'nice',
#   'present',
#   'old',
#   'last',
#   'right',
#   'offensive',
#   'aware',
#   'first',
#   'past',
#   'happier',
#   'police',
#   'unfrozen'],
#  ['rich',
#   'lower',
#   'rich',
#   'wealthy',
#   'unwilling',
#   'rich',
#   'young',
#   'neighbouring',
#   'funeral',
#   'past'],
#  ['similar', 'first', 'great', 'best', 'new'],
#  ['isolated',
#   'sumerian',
#   'demonic',
#   'evil',
#   'outside',
#   'stabs',
#   'scotty',
#   'scotty',
#   'possessed',
#   'possessed',
#   'ceremonial',
#   'impale',
#   'outside',
#   'extra',
#   'strange',
#   'mysterious',
#   'numerous',
#   'little',
#   'scotty',
#   'several',
#   'inanimate',
#   'demon',
#   'upon'],
#  ['exclusive',
#   'french',
#   'idyllic',
#   'beautiful',
#   'loving',
#   'deceptive',
#   'idyllic',
#   'uncertain'],
#  ['obituary'],
#  ['local', 'magic', 'real', 'powerful'],
#  ['calm',
#   'recent',
#   'affluent',
#   'active',
#   'young',
#   'several',
#   'big',
#   'right',
#   'keep',
#   'inevitable',
#   'undercover',
#   'original',
#   'complete',
#   'undercover'],
#  ['greek',
#   'intervene',
#   'fable',
#   'clear',
#   'great',
#   'first',
#   'crude',
#   'lifestyle',
#   'basketball',
#   'perfect',
#   'last',
#   'individual'],
#  ['weak',
#   'secret',
#   'higher',
#   'entombment',
#   'alive',
#   'wish',
#   'secret',
#   'total'],
#  ['pier', 'free', 'sick', 'absent', 'chase'],
#  ['jewish', 'german', 'alive', 'punishable', 'false', 'desperate', 'new'],
#  ['independent', 'much', 'perfect', 'darkest'],
#  ['robots',
#   'secret',
#   'similar',
#   'front',
#   'mechanical',
#   'rarest',
#   'local',
#   'nearest',
#   'high',
#   'dear',
#   'bound',
#   'industrial',
#   'lower',
#   'upper',
#   'molten',
#   'hot',
#   'latest',
#   'mechanical',
#   'wonderful'],
#  ['typical',
#   'canadian',
#   'older',
#   'last',
#   'first',
#   'poorest',
#   'gated',
#   'junior',
#   'rural',
#   'lush',
#   'first',
#   'handicapped',
#   'developed',
#   'third',
#   'secluded',
#   'orchid',
#   'obnoxious',
#   'rich',
#   'reluctant',
#   'supernatural',
#   'real',
#   'johnny',
#   'local',
#   'real',
#   'local',
#   'supernatural',
#   'whole',
#   'new'],
#  ['divorced', 'first', 'respective', 'public', 'controversial', 'usual'],
#  ['special', 'best', 'permanent'],
#  ['young',
#   'suburban',
#   'shady',
#   'secluded',
#   'heavy',
#   'personal',
#   'normal',
#   'angry',
#   'cynical',
#   'happy',
#   'unable',
#   'internal',
#   'unable',
#   'wounded',
#   'medical',
#   'black',
#   'deeper',
#   'animal'],
#  ['nineteenth', 'new', 'content', 'small', 'stern', 'treachery'],
#  ['unable', 'wannabe', 'secret', 'new', 'younger', 'true'],
#  ['little', 'childish', 'first', 'several', 'light', 'much', 'older'],
#  ['young',
#   'jewish',
#   'first',
#   'leading',
#   'older',
#   'jewish',
#   'forged',
#   'imminent',
#   'german',
#   'usual',
#   'earlier',
#   'tragic',
#   'motionless',
#   'larger',
#   'occupying',
#   'german',
#   'popular',
#   'cultural',
#   'former',
#   'former',
#   'medical',
#   'former',
#   'jewish'],
#  ['local', 'real'],
#  ['american',
#   'occasional',
#   'intimate',
#   'much',
#   'past',
#   'smart',
#   'sixth',
#   'special',
#   'good',
#   'liberated',
#   'prisoner',
#   'free',
#   'certain'],
#  ['blond',
#   'mad',
#   'young',
#   'local',
#   'strong',
#   'ghostly',
#   'mysterious',
#   'blind',
#   'first',
#   'eerie',
#   'similar',
#   'metaphysical',
#   'tangled',
#   'ambivalent',
#   'confident',
#   'younger',
#   'banal',
#   'wounded',
#   'longer',
#   'dead',
#   'suspicious',
#   'blind',
#   'interested',
#   'last',
#   'first',
#   'true',
#   'attracted',
#   'ambivalent',
#   'earlier',
#   'narrative',
#   'apparent',
#   'emotional',
#   'metaphysical',
#   'previous',
#   'sighted',
#   'free',
#   'happy',
#   'earlier'],
#  ['long', 'stillborn', 'angry', 'bitter'],
#  ['opening',
#   'televised',
#   'genocidal',
#   'humanoid',
#   'present',
#   'main',
#   'new',
#   'special',
#   'short',
#   'first',
#   'enough',
#   'mountainous',
#   'several',
#   'twelve',
#   'dead',
#   'religious',
#   'safe',
#   'old',
#   'military',
#   'first',
#   'several',
#   'second',
#   'several',
#   'numerous',
#   'dead',
#   'humanoid',
#   'dead',
#   'unharmed',
#   'first',
#   'elephant',
#   'original',
#   'distraught',
#   'angry',
#   'special',
#   'humanoid',
#   'last',
#   'manipulated',
#   'suicide',
#   'second',
#   'second',
#   'fragile',
#   'psychological',
#   'stranded',
#   'last',
#   'local',
#   'various',
#   'less',
#   'repeated',
#   'young',
#   'humanoid',
#   'second',
#   'main',
#   'terrifying',
#   'gamma',
#   'hear',
#   'dark'],
#  ['powerful', 'large', 'powerful', 'surprising', 'future'],
#  ['new',
#   'dead',
#   'barbed',
#   'right',
#   'numerous',
#   'mutilated',
#   'decomposed',
#   'long',
#   'dead',
#   'frantic',
#   'broken',
#   'alive',
#   'deformed',
#   'loose',
#   'unclear',
#   'murderous'],
#  ['short', 'thick', 'pubic', 'second', 'young'],
#  ['dreadful', 'second', 'alcoholic', 'personal', 'petty', 'intruded'],
#  ['younger', 'beautiful', 'rustic', 'whole'],
#  ['young', 'strong'],
#  ['young', 'special', 'entire', 'private', 'free'],
#  ['investigated',
#   'complete',
#   'suspicious',
#   'diligent',
#   'conclusive',
#   'grateful',
#   'unable',
#   'gainful',
#   'great',
#   'innocent',
#   'good'],
#  ['last', 'surprising', 'mutual', 'staunch'],
#  ['young',
#   'worse',
#   'best',
#   'much',
#   'theatre',
#   'best',
#   'first',
#   'guilty',
#   'good',
#   'outlaws',
#   'united'],
#  ['fictional'],
#  ['opening',
#   'earlier',
#   'young',
#   'dead',
#   'striptease',
#   'various',
#   'comic',
#   'undead',
#   'sexy',
#   'black'],
#  ['former',
#   'old',
#   'military',
#   'dead',
#   'large',
#   'responsible',
#   'last',
#   'hummin',
#   'undead',
#   'german',
#   'second',
#   'naked',
#   'illuminated',
#   'general'],
#  ['dark',
#   'big',
#   'wide',
#   'dead',
#   'shot',
#   'third',
#   'full',
#   'public',
#   'rather',
#   'angry',
#   'investigative',
#   'public',
#   'secret',
#   'angry'],
#  ['recent', 'old', 'coming', 'gigantic', 'close', 'beautiful', 'happy'],
#  ['brilliant', 'rich', 'villainous', 'real', 'dubious'],
#  ['forbidden', 'local', 'unable', 'bawdy', 'much', 'titular', 'acclaimed'],
#  [],
#  ['small',
#   'best',
#   'funeral',
#   'obvious',
#   'little',
#   'eccentric',
#   'amazing',
#   'stunning',
#   'responsible',
#   'comic'],
#  ['last',
#   'drunken',
#   'single',
#   'large',
#   'jagged',
#   'illiterative',
#   'packed',
#   'grateful',
#   'finest',
#   'undergraduate',
#   'mischievous',
#   'royal',
#   'real',
#   'uncovered',
#   'real',
#   'greatest',
#   'arrive',
#   'angry',
#   'angry',
#   'former',
#   'personal',
#   'angry',
#   'usual'],
#  ['american',
#   'new',
#   'new',
#   'incomplete',
#   'helpless',
#   'little',
#   'unwanted',
#   'sexual',
#   'vivid',
#   'second',
#   'secret',
#   'forty',
#   'legendary',
#   'local',
#   'changing',
#   'top',
#   'unfortunately',
#   'personal',
#   'entire',
#   'little',
#   'whole',
#   'unable',
#   'oral',
#   'drive',
#   'attracted',
#   'sexual',
#   'offensive',
#   'laid',
#   'original',
#   'outside',
#   'last',
#   'online',
#   'cleaner'],
#  ['contemporary',
#   'provocative',
#   'particular',
#   'indian',
#   'broken',
#   'old',
#   'younger',
#   'pivotal',
#   'clandestine',
#   'adamant',
#   'police',
#   'hot',
#   'social'],
#  ['jean',
#   'interested',
#   'rich',
#   'great',
#   'memorable',
#   'unrealistic',
#   'idealized',
#   'opposite',
#   'enough',
#   'rich',
#   'poor',
#   'happy',
#   'last',
#   'imaginated'],
#  ['best',
#   'clear',
#   'angrier',
#   'prepared',
#   'former',
#   'tough',
#   'small',
#   'wiry',
#   'jewish',
#   'alpha',
#   'first',
#   'desperate',
#   'double',
#   'corrosive',
#   'weak',
#   'maximum',
#   'aware',
#   'entire',
#   'last'],
#  ['young', 'shady', 'suspicious', 'narrow', 'dead', 'bloody'],
#  ['small', 'second', 'first', 'entire', 'depressed'],
#  ['canadian',
#   'determined',
#   'real',
#   'enough',
#   'old',
#   'worse',
#   'old',
#   'journalistic',
#   'surreal',
#   'perilous',
#   'unfinished',
#   'canadian',
#   'true',
#   'last'],
#  [],
#  ['local',
#   'free',
#   'evil',
#   'secret',
#   'certain',
#   'musical',
#   'adulterated',
#   'neighboring',
#   'former',
#   'mysterious',
#   'full',
#   'shuttered',
#   'old',
#   'galactic',
#   'involved',
#   'great',
#   'nervous',
#   'floppy',
#   'unable',
#   'survive',
#   'apparent',
#   'brainwashed',
#   'first',
#   'possible',
#   'large',
#   'free',
#   'tainted',
#   'true',
#   'contaminated'],
#  ['eternal', 'mysterious', 'young'],
#  ['unable',
#   'supernatural',
#   'dead',
#   'antique',
#   'alive',
#   'weird',
#   'dead',
#   'accomplished',
#   'unauthorised'],
#  ['dutch'],
#  ['big', 'best'],
#  ['bent', 'second', 'french', 'old', 'close', 'french', 'true'],
#  ['stress', 'meek', 'high', 'promising'],
#  ['longest', 'willing', 'new'],
#  ['mad', 'arrive', 'enough', 'last', 'distracted'],
#  ['long', 'apt', 'real', 'touching'],
#  ['dissatisfied', 'secret', 'secret', 'greater', 'secret', 'british'],
#  ['local', 'secret', 'greatest', 'amateur'],
#  ['previous', 'various', 'blind', 'real', 'young', 'corday'],
#  ['small', 'lasting', 'good', 'best', 'watchful', 'difficult'],
#  ['former',
#   'blind',
#   'responsible',
#   'suspected',
#   'prime',
#   'dark',
#   'former',
#   'north',
#   'tragic'],
#  ['village', 'manu', 'negative'],
#  ['puddy',
#   'puddy',
#   'metronome',
#   'puddy',
#   'heavy',
#   'new',
#   'aware',
#   'intruding',
#   'legitimately',
#   'angry',
#   'calm',
#   'polite',
#   'lisping',
#   'several',
#   'rapid',
#   'direct',
#   'vertical',
#   'tiny',
#   'stops',
#   'several',
#   'puddy'],
#  ['police', 'police', 'first'],
#  ['historical', 'hypothetical', 'similar'],
#  ['forced',
#   'elderly',
#   'spanish',
#   'vivacious',
#   'former',
#   'young',
#   'pretty',
#   'entire',
#   'pirates',
#   'southern',
#   'arrive',
#   'courtesan',
#   'french',
#   'new',
#   'uncomfortable',
#   'short',
#   'beautiful',
#   'following',
#   'aware',
#   'dressing',
#   'unwelcome',
#   'unable',
#   'least',
#   'french',
#   'true',
#   'french',
#   'loving',
#   'older',
#   'late',
#   'song',
#   'locked',
#   'western'],
#  ['fictional',
#   'mongolian',
#   'fragmented',
#   'impressionistic',
#   'dreamlike',
#   'free',
#   'young',
#   'mongolian'],
#  ['junior',
#   'high',
#   'strict',
#   'new',
#   'high',
#   'good',
#   'italian',
#   'much',
#   'sick',
#   'sick',
#   'real',
#   'sent',
#   'fake',
#   'angry',
#   'entire',
#   'new',
#   'high',
#   'proud',
#   'last',
#   'whole'],
#  ['young', 'jewish', 'young', 'strong', 'questionable', 'long', 'happy'],
#  ['wealthy', 'safe', 'secret', 'former', 'new'],
#  ['elderly', 'first'],
#  ['small',
#   'serial',
#   'young',
#   'turned',
#   'first',
#   'unable',
#   'policewoman',
#   'former',
#   'scam',
#   'blackmail',
#   'porn',
#   'secret',
#   'cautious',
#   'confident',
#   'proud',
#   'former',
#   'dead',
#   'outside',
#   'nearby',
#   'septic',
#   'first',
#   'alive',
#   'unconscious',
#   'hidden',
#   'young',
#   'deputy',
#   'dead',
#   'right',
#   'septic',
#   'real',
#   'outside',
#   'front',
#   'alive',
#   'random',
#   'neurological',
#   'blank',
#   'small',
#   'fat',
#   'dead',
#   'unbeknown',
#   'special',
#   'fat',
#   'special',
#   'angry',
#   'fat',
#   'small',
#   'concentrated',
#   'empty',
#   'mean',
#   'large',
#   'sugary',
#   'poisoned',
#   'stuffed',
#   'several',
#   'large',
#   'old',
#   'old',
#   'poisoned',
#   'old',
#   'bloody'],
#  ['high',
#   'chief',
#   'new',
#   'sour',
#   'abrasive',
#   'powerful',
#   'musical',
#   'lead',
#   'particular',
#   'heavy',
#   'independent',
#   'less',
#   'original',
#   'forecasted',
#   'major',
#   'american',
#   'limited',
#   'positive',
#   'financial'],
#  ['single',
#   'japanese',
#   'small',
#   'crowded',
#   'chinese',
#   'possible',
#   'superfluous',
#   'sharp',
#   'extra',
#   'good',
#   'much',
#   'sorry',
#   'buddhist',
#   'beautiful',
#   'old',
#   'lascivious',
#   'young',
#   'old',
#   'clear',
#   'sexual',
#   'headstrong',
#   'upscale',
#   'drunk',
#   'novel',
#   'second',
#   'new',
#   'xiao',
#   'little',
#   'japanese',
#   'feudal',
#   'traditional',
#   'xiao',
#   'xiao',
#   'unpatriotic',
#   'xiao',
#   'japanese',
#   'broken',
#   'xiao',
#   'happy',
#   'usurped',
#   'unclear',
#   'first'],
#  ['us',
#   'deadly',
#   'strange',
#   'old',
#   'colicky',
#   'isolated',
#   'small',
#   'activated',
#   'unnecessary',
#   'major',
#   'right',
#   'advanced',
#   'extraterrestrial',
#   'amino',
#   'airborne',
#   'acidotic',
#   'initial',
#   'aware',
#   'temporary',
#   'various',
#   'small',
#   'tactical',
#   'quarantine',
#   'exponential',
#   'quarantine',
#   'plastic',
#   'quarantine',
#   'several',
#   'virulent',
#   'closest',
#   'international',
#   'unsuccessful',
#   'separate',
#   'binary',
#   'bitmap',
#   'interlocking',
#   'new',
#   'controversial',
#   'encoded',
#   'confidential',
#   'organic',
#   'natural',
#   'large',
#   'quarantined',
#   'sufficient',
#   'enough',
#   'quarantined',
#   'future',
#   'photosensitive',
#   'lab',
#   'main',
#   'exhaust',
#   'radioactive',
#   'right',
#   'radioactive',
#   'saved',
#   'containment',
#   'interlocking',
#   'present',
#   'ontological'],
#  ['christian',
#   'younger',
#   'pet',
#   'peaceful',
#   'real',
#   'good',
#   'real',
#   'shashtri',
#   'underworld',
#   'hidden',
#   'hilarious',
#   'individual'],
#  ['young', 'unable', 'unable', 'talkative', 'daily', 'prime'],
# ...
#   'acquitted',
#   'last'],
#  ['unconscious', 'entire', 'subconscious', 'rich'],
#  ['late',
#   'young',
#   'closest',
#   'dead',
#   'forgotten',
#   'first',
#   'unhappy',
#   'painful',
#   'less',
#   'worthy',
#   'demanding',
#   'intellectual',
#   'spends'],
#  ['front',
#   'thorough',
#   'full',
#   'electrical',
#   'large',
#   'various',
#   'chaotic',
#   'short'],
#  ['special', 'new', 'safe'],
#  ['dead',
#   'british',
#   'british',
#   'small',
#   'german',
#   'senior',
#   'british',
#   'alive',
#   'long',
#   'official',
#   'perfect',
#   'german',
#   'medical'],
#  ['great',
#   'heavy',
#   'old',
#   'diverse',
#   'lethal',
#   'free',
#   'old',
#   'sharptooth',
#   'sharp',
#   'small',
#   'mammal',
#   'prejudiced',
#   'following'],
#  ['carefree', 'mysterious', 'free'],
#  ['young',
#   'horrid',
#   'good',
#   'local',
#   'burnt',
#   'free',
#   'free',
#   'bear',
#   'wooden',
#   'new',
#   'unable',
#   'free',
#   'second',
#   'unconscious',
#   'solid',
#   'similar',
#   'old',
#   'nearby'],
#  ['nearby',
#   'stupid',
#   'young',
#   'best',
#   'forrest',
#   'forrest',
#   'forrest',
#   'following',
#   'chinese',
#   'numerous',
#   'embittered',
#   'scornful',
#   'first',
#   'first',
#   'little',
#   'forrest',
#   'early',
#   'forrest',
#   'young',
#   'first',
#   'first'],
#  ['worst', 'little', 'isolated', 'long', 'epic', 'true', 'demonic'],
#  ['rich', 'poor', 'real', 'real', 'old', 'big', 'first', 'sheriff'],
#  ['young', 'first', 'outstanding', 'keen', 'unbeknown', 'ill'],
#  ['rural',
#   'librarian',
#   'crashed',
#   'dead',
#   'bag',
#   'full',
#   'unmarked',
#   'secret',
#   'larger',
#   'old',
#   'consciousness',
#   'accidental',
#   'ridiculous',
#   'old',
#   'solid',
#   'rehearsed',
#   'whole',
#   'feels',
#   'downed',
#   'lost',
#   'lost',
#   'real',
#   'upstanding',
#   'capable',
#   'unexpected',
#   'ransom',
#   'serial',
#   'old'],
#  ['suburban',
#   'devoted',
#   'commercial',
#   'shaky',
#   'weekly',
#   'greater',
#   'greater',
#   'unlikely'],
#  [],
#  ['average',
#   'young',
#   'cryogenic',
#   'insectoid',
#   'soldier',
#   'first',
#   'heartless',
#   'limited',
#   'dead',
#   'deep',
#   'sharp',
#   'last',
#   'remaining',
#   'turning',
#   'clear',
#   'shuttle',
#   'bent',
#   'new',
#   'double',
#   'stronger',
#   'genetic',
#   'intensive',
#   'inexperienced',
#   'adept',
#   'great',
#   'young',
#   'much',
#   'largest',
#   'negative',
#   'little',
#   'second',
#   'current',
#   'military',
#   'high',
#   'medical',
#   'ignorant',
#   'unknowing',
#   'several',
#   'medical',
#   'medical',
#   'military',
#   'military',
#   'medical',
#   'depressed',
#   'become',
#   'new',
#   'impenetrable',
#   'first',
#   'local',
#   'crystal',
#   'military',
#   'firefight',
#   'last',
#   'former',
#   'long',
#   'safe'],
#  ['local',
#   'mysterious',
#   'wet',
#   'local',
#   'young',
#   'complete',
#   'lake',
#   'several',
#   'clear'],
#  ['complete', 'literal', 'smaller', 'major', 'red', 'victorious'],
#  ['married',
#   'difficult',
#   'numerous',
#   'old',
#   'secret',
#   'unborn',
#   'late',
#   'second',
#   'instant',
#   'sisterly',
#   'young',
#   'attached',
#   'last',
#   'flaky',
#   'unstable',
#   'scary',
#   'threatening',
#   'public',
#   'apparent',
#   'apparent',
#   'secret',
#   'medical',
#   'nick',
#   'old'],
#  ['small', 'large', 'tumble', 'large'],
#  ['much', 'lawful'],
#  ['perfect'],
#  ['possible', 'large', 'small', 'rural', 'various', 'high', 'first'],
#  ['orphan', 'underworld', 'expressive'],
#  ['real'],
#  ['late',
#   'german',
#   'russian',
#   'russian',
#   'american',
#   'german',
#   'american',
#   'german'],
#  ['eldest',
#   'perpetual',
#   'rich',
#   'unlucky',
#   'lucky',
#   'hot',
#   'runaway',
#   'good',
#   'entire',
#   'predictable'],
#  ['professional',
#   'actual',
#   'professional',
#   'key',
#   'climactic',
#   'promotional',
#   'long',
#   'free'],
#  ['careless', 'actual', 'assistant', 'drunk', 'last', 'slain'],
#  ['precise',
#   'convertible',
#   'trivial',
#   'young',
#   'young',
#   'unwilling',
#   'unable',
#   'casual',
#   'loud',
#   'direct',
#   'coarse',
#   'likable',
#   'complete',
#   'impulsive',
#   'high',
#   'short',
#   'risky',
#   'younger',
#   'rocky',
#   'bloodied',
#   'shocked'],
#  ['unsuccessful',
#   'unsuccessful',
#   'piano',
#   'lower',
#   'talented',
#   'significant',
#   'good',
#   'crazy',
#   'white',
#   'crazy'],
#  ['fictional',
#   'nearby',
#   'ablaze',
#   'ubiquitous',
#   'unsatisfied',
#   'complete',
#   'ballistic',
#   'several',
#   'unnoticed',
#   'fake',
#   'fake',
#   'worthless',
#   'several',
#   'forest',
#   'forest',
#   'least',
#   'stolen',
#   'local',
#   'personal'],
#  ['outraged'],
#  ['total',
#   'heartless',
#   'uncaring',
#   'awful',
#   'innocent',
#   'evil',
#   'horrible',
#   'responsible',
#   'last',
#   'good'],
#  ['powerful', 'influential', 'superior', 'beautiful'],
#  ['past',
#   'teenage',
#   'medical',
#   'capable',
#   'basic',
#   'key',
#   'young',
#   'younger',
#   'teenage',
#   'explicit',
#   'small',
#   'former',
#   'dead',
#   'lifelike',
#   'previous',
#   'mindless',
#   'resemble',
#   'normal',
#   'first',
#   'pet',
#   'unexpected',
#   'utter',
#   'unclear',
#   'dead',
#   'alive',
#   'insane',
#   'past'],
#  ['beautiful',
#   'suburban',
#   'wealthy',
#   'best',
#   'prominent',
#   'latest',
#   'local',
#   'marital',
#   'idyllic',
#   'financial',
#   'unraveling',
#   'fractured',
#   'new',
#   'real',
#   'ex',
#   'special'],
#  ['good', 'diverse', 'cultural', 'young', 'paternal', 'grand'],
#  ['timequest',
#   'present',
#   'past',
#   'particular',
#   'future',
#   'cynical',
#   'respective',
#   'public',
#   'full',
#   'elderly',
#   'old'],
#  ['late', 'sporadic', 'northern', 'uncertain', 'invisible'],
#  ['least',
#   'desirable',
#   'accidental',
#   'beautiful',
#   'new',
#   'downtrodden',
#   'mysterious',
#   'young',
#   'last',
#   'front',
#   'bugged',
#   'powerless',
#   'dead',
#   'dead',
#   'sharky',
#   'dead',
#   'alive',
#   'old',
#   'dead',
#   'sharky',
#   'considerable',
#   'agitated',
#   'upper'],
#  ['young',
#   'much',
#   'possible',
#   'sixth',
#   'best',
#   'shy',
#   'embarrassed',
#   'first',
#   'second',
#   'old',
#   'whole',
#   'special',
#   'large',
#   'old',
#   'enlightened',
#   'strong',
#   'messy',
#   'challenged',
#   'opposite',
#   'finest',
#   'table',
#   'whole',
#   'good'],
#  ['local'],
#  ['unable',
#   'small',
#   'guilty',
#   'real',
#   'unabel',
#   'right',
#   'middle',
#   'false',
#   'old'],
#  [],
#  ['young',
#   'shy',
#   'nearby',
#   'shotgun',
#   'local',
#   'dead',
#   'medical',
#   'alive',
#   'alive',
#   'dead',
#   'evil',
#   'previous',
#   'teeth',
#   'teeth',
#   'gloved',
#   'telekinetic',
#   'dead',
#   'alive',
#   'good'],
#  ['social', 'first', 'french', 'highest', 'french', 'commercial', 'less'],
#  ['big', 'illegal', 'young', 'irks', 'happy', 'normal'],
#  ['best', 'single'],
#  ['impregnate', 'marital', 'younger', 'happy', 'uncomfortable', 'fast'],
#  ['military'],
#  ['good',
#   'latter',
#   'staunch',
#   'great',
#   'local',
#   'much',
#   'various',
#   'lead',
#   'stellar',
#   'versatile',
#   'good'],
#  ['total', 'thin', 'similar', 'suicide', 'dice'],
#  ['old',
#   'outside',
#   'angry',
#   'closed',
#   'outside',
#   'small',
#   'artificial',
#   'artificial',
#   'last',
#   'alive',
#   'artificial'],
#  ['new',
#   'new',
#   'tequila',
#   'judgmental',
#   'nervous',
#   'good',
#   'first',
#   'nearest',
#   'nearest',
#   'new',
#   'good',
#   'medical',
#   'sick',
#   'extensive',
#   'broken',
#   'injured',
#   'hobble',
#   'numerous',
#   'much',
#   'couch',
#   'cistern',
#   'poisonous',
#   'cistern',
#   'front',
#   'locked',
#   'stupid',
#   'rich',
#   'big',
#   'dead',
#   'high',
#   'short',
#   'dead'],
#  ['young',
#   'former',
#   'native',
#   'nearby',
#   'young',
#   'coral',
#   'dead',
#   'strange',
#   'new',
#   'initial',
#   'strange',
#   'asleep',
#   'dead',
#   'last',
#   'great'],
#  ['italian', 'ancient', 'best'],
#  ['active', 'social', 'happy'],
#  ['place', 'several', 'first', 'imprisoned', 'past', 'first', 'shot', 'local'],
#  ['old', 'military', 'last', 'japanese', 'last'],
#  ['broken',
#   'sacred',
#   'thousand',
#   'local',
#   'muscular',
#   'secret',
#   'social',
#   'free',
#   'new',
#   'empty',
#   'weak',
#   'single',
#   'meet',
#   'musical',
#   'skinny',
#   'former',
#   'ill',
#   'drunken',
#   'last',
#   'major',
#   'old'],
#  ['dramatized',
#   'real',
#   'fictitious',
#   'dead',
#   'coincidental',
#   'dramatic',
#   'necessary',
#   'amphibious',
#   'married',
#   'south',
#   'ongoing',
#   'major',
#   'antique',
#   'south',
#   'safe',
#   'north',
#   'second',
#   'former',
#   'south',
#   'north',
#   'south',
#   'american'],
#  ['beautiful',
#   'talented',
#   'triumphal',
#   'certain',
#   'vivacious',
#   'avaricious',
#   'opportunistic',
#   'certain',
#   'acting',
#   'verminous',
#   'elaborate',
#   'bearded',
#   'french',
#   'cannily',
#   'sergeant',
#   'artificial',
#   'aware',
#   'suspicious',
#   'unsympathetic'],
#  ['strict',
#   'outside',
#   'younger',
#   'happy',
#   'lucky',
#   'worse',
#   'dead',
#   'alive',
#   'real'],
#  ['earliest',
#   'first',
#   'poor',
#   'young',
#   'little',
#   'full',
#   'little',
#   'third',
#   'young',
#   'full',
#   'young',
#   'third',
#   'young'],
#  ['good', 'first'],
#  ['large',
#   'new',
#   'full',
#   'suspicious',
#   'secretive',
#   'international',
#   'secret'],
#  ['rich',
#   'young',
#   'much',
#   'detective',
#   'true',
#   'rich',
#   'wealthy',
#   'good',
#   'tough',
#   'rich',
#   'equal',
#   'christian'],
#  ['old',
#   'best',
#   'young',
#   'junior',
#   'high',
#   'real',
#   'first',
#   'green',
#   'first',
#   'young',
#   'visible',
#   'urgent',
#   'invisible'],
#  ['high',
#   'song',
#   'scary',
#   'song',
#   'song',
#   'long',
#   'big',
#   'song',
#   'song',
#   'romp',
#   'dorothy',
#   'song',
#   'magician',
#   'top',
#   'magic',
#   'magic',
#   'big',
#   'song',
#   'extra',
#   'blubbering',
#   'top',
#   'song',
#   'teddy',
#   'teddy',
#   'song',
#   'plastic',
#   'song',
#   'song',
#   'great'],
#  ['less', 'intact', 'old', 'much', 'american', 'underworld'],
#  ['young', 'greater', 'jean', 'new', 'unattached', 'rich', 'poor'],
#  ['virginal',
#   'young',
#   'exclusive',
#   'british',
#   'right',
#   'first',
#   'sexual',
#   'first',
#   'asleep',
#   'unable',
#   'full'],
#  [],
#  ['young',
#   'comic',
#   'new',
#   'beautiful',
#   'contentious',
#   'comic',
#   'several',
#   'comic',
#   'familiar'],
#  ['french', 'mysterious', 'hidden', 'small', 'isolated', 'subjective'],
#  ['useful', 'large', 'short', 'long', 'major', 'small'],
#  ['old',
#   'funeral',
#   'good',
#   'suburbs',
#   'south',
#   'old',
#   'gold',
#   'longer',
#   'adult',
#   'dead',
#   'dark',
#   'gray',
#   'horrible',
#   'angry',
#   'real',
#   'missing',
#   'silent',
#   'real',
#   'dead',
#   'south',
#   'social',
#   'social',
#   'first',
#   'full',
#   'determined',
#   'bible',
#   'close',
#   'bible',
#   'outside',
#   'right',
#   'last',
#   'watchful',
#   'nervous',
#   'unsuccessful',
#   'good',
#   'old',
#   'convertible',
#   'racist',
#   'dead',
#   'actual',
#   'rather',
#   'free'],
#  ['expensive', 'shot'],
#  ['angry', 'alive', 'unborn'],
#  ['young', 'local', 'bent'],
#  ['american'],
#  ['theatre', 'undiscovered', 'local'],
#  ['suspicious', 'japanese', 'early', 'painful', 'hostile'],
#  ['american',
#   'uninhabited',
#   'asian',
#   'deserted',
#   'tropical',
#   'second',
#   'deadly',
#   'victorious'],
#  ['american',
#   'large',
#   'dead',
#   'dead',
#   'medical',
#   'local',
#   'local',
#   'epidemic',
#   'tough',
#   'widespread',
#   'deadly',
#   'epidemic',
#   'clear',
#   'concurrent',
#   'tubercular',
#   'infected'],
#  ['unforgivable', 'big', 'special'],
#  ['notorious',
#   'last',
#   'great',
#   'immense',
#   'native',
#   'french',
#   'unfazed',
#   'local'],
#  ['swedish', 'cerebral', 'proficient', 'swedish', 'much', 'unexpected'],
#  ['young',
#   'new',
#   'eldest',
#   'private',
#   'close',
#   'last',
#   'mental',
#   'small',
#   'unconscious',
#   'desperate'],
#  ['elite', 'best', 'suicide', 'aware', 'fuckin', 'forest', 'hiding', 'alive'],
#  ['popular', 'key', 'charitable', 'assistant', 'illegal', 'torrential'],
#  ['shady',
#   'little',
#   'deep',
#   'russian',
#   'hostile',
#   'american',
#   'hot',
#   'false',
#   'illegal',
#   'desperate'],
#  ['personal',
#   'stumble',
#   'injured',
#   'nearby',
#   'combined',
#   'new',
#   'giant',
#   'giant'],
#  ['small',
#   'southern',
#   'denied',
#   'stubborn',
#   'eccentric',
#   'private',
#   'subsequent',
#   'young',
#   'rich',
#   'latter',
#   'infant',
#   'adopted',
#   'unmoved',
#   'empty',
#   'angry',
#   'commercial',
#   'enraged',
#   'previous',
#   'second',
#   'young',
#   'ambitious',
#   'international',
#   'full',
#   'international',
#   'original'],
#  ['free', 'spoilt', 'insensitive', 'guilty', 'poor', 'good'],
#  ['tough'],
#  ['wealthy',
#   'blasé',
#   'chic',
#   'upscale',
#   'socialite',
#   'sadistic',
#   'older',
#   'several',
#   'simulated',
#   'enormous',
#   'anxious',
#   'tense',
#   'separate'],
#  ['local',
#   'magical',
#   'nap',
#   'tear',
#   'tear',
#   'magical',
#   'follow',
#   'magic',
#   'local',
#   'local',
#   'new',
#   'adjacent',
#   'past',
#   'pacifistic',
#   'laboratory',
#   'mechanical',
#   'royal',
#   'high',
#   'strange',
#   'content',
#   'royal',
#   'fears',
#   'reformed',
#   'formidable',
#   'infuriated',
#   'central'],
#  ['latest',
#   'first',
#   'unlocked',
#   'cynical',
#   'numerous',
#   'safe',
#   'pretty',
#   'first',
#   'married',
#   'compromising',
#   'last',
#   'previous',
#   'suspicious',
#   'illegitimate',
#   'young',
#   'legitimate'],
#  ['first',
#   'young',
#   'dead',
#   'younger',
#   'closer',
#   'young',
#   'useful',
#   'false',
#   'alive',
#   'unstable',
#   'necessary'],
#  ['rhythmic',
#   'close',
#   'spaniel',
#   'outside',
#   'much',
#   'runaway',
#   'shallow',
#   'nightmarish'],
#  ['sathish', 'eswarapandian', 'eswarapandian', 'harmless'],
#  ['best',
#   'last',
#   'old',
#   'deciding',
#   'depressed',
#   'hopeless',
#   'unhealthy',
#   'celtic',
#   'selfish',
#   'stumble',
#   'first',
#   'first',
#   'fair',
#   'hot',
#   'commercial',
#   'skipping',
#   'antagonistic',
#   'local',
#   'first',
#   'leading',
#   'little'],
#  ['wealthy',
#   'large',
#   'prosthetic',
#   'best',
#   'former',
#   'alive',
#   'unable',
#   'perfect',
#   'distorted',
#   'previous',
#   'angry',
#   'confused',
#   'mental',
#   'several',
#   'nearby',
#   'cryonic',
#   'familiar',
#   'lucid',
#   'anxious',
#   'breaks',
#   'free',
#   'tech',
#   'empty',
#   'tech',
#   'cryonic',
#   'severe',
#   'lucid',
#   'subconscious',
#   'literal'],
#  ['wealthy',
#   'young',
#   'high',
#   'rich',
#   'popular',
#   'opposite',
#   'mousy',
#   'bed',
#   'vulnerable',
#   'unexperienced',
#   'guilty',
#   'sixteen',
#   'powerful',
#   'high',
#   'personal',
#   'closer',
#   'biggest',
#   'personal',
#   'simple',
#   'closer'],
#  ['small',
#   'rural',
#   'former',
#   'interested',
#   'menial',
#   'local',
#   'large',
#   'tethered',
#   'menial',
#   'local',
#   'new',
#   'social',
#   'local',
#   'local',
#   'physical',
#   'innocuous',
#   'innocent',
#   'fateful',
#   'pornographic',
#   'uncomfortable',
#   'outside',
#   'unable',
#   'following',
#   'local',
#   'cheerful',
#   'local',
#   'pure',
#   'little',
#   'unable',
#   'lonely',
#   'free',
#   'black'],
#  ['new',
#   'illegal',
#   'much',
#   'larger',
#   'effective',
#   'chinese',
#   'american',
#   'lingerie',
#   'unaware',
#   'latest',
#   'shredded',
#   'long',
#   'much',
#   'large',
#   'naked'],
#  ['weak', 'wounded', 'large', 'christian', 'begin', 'aghast', 'astonished'],
#  ['former',
#   'prosperous',
#   'ineffective',
#   'free',
#   'true',
#   'dead',
#   'irresponsible',
#   'animal',
#   'antagonistic',
#   'equal',
#   'young',
#   'extra',
#   'plentiful',
#   'special',
#   'personal',
#   'young',
#   'easier',
#   'animal',
#   'animal',
#   'old',
#   'animal',
#   'long',
#   'local',
#   'attempted',
#   'false',
#   'outside',
#   'financial',
#   'hostile',
#   'great',
#   'futile',
#   'phony',
#   'last',
#   'guard',
#   'upright',
#   'wear',
#   'seven',
#   'single',
#   'equal',
#   'equal',
#   'outside',
#   'least',
#   'worse',
#   'smashed'],
#  ['high',
#   'apprehensive',
#   'conscious',
#   'regimented',
#   'meticulous',
#   'first',
#   'thin',
#   'okay',
#   'complacent',
#   'anorexic',
#   'reluctant',
#   'sick',
#   'incompetent',
#   'incapable'],
#  ['early',
#   'former',
#   'experimental',
#   'psychedelic',
#   'american',
#   'original',
#   'original',
#   'specific',
#   'full',
#   'mandolin'],
#  ['mysterious',
#   'last',
#   'special',
#   'victorious',
#   'close',
#   'evil',
#   'possessed',
#   'present',
#   'alive',
#   'alive',
#   'right',
#   'secret',
#   'small',
#   'strange',
#   'first',
#   'giant',
#   'dark',
#   'unleashed',
#   'silent'],
#  ['big', 'younger', 'single', 'ten', 'old', 'first', 'new', 'adopted'],
#  ['obscene', 'young', 'unable', 'asian'],
#  ['military',
#   'military',
#   'automatic',
#   'maximum',
#   'overdrive',
#   'military',
#   'military'],
#  ['north', 'illegal', 'chinese', 'outside'],
#  ['little',
#   'favorite',
#   'new',
#   'brokenhearted',
#   'obnoxious',
#   'major',
#   'continued'],
#  ['young', 'tough', 'decorated', 'hidden', 'dark', 'certain', 'rican'],
#  ['sexy', 'lifelong', 'innate', 'occasional', 'comic', 'true', 'possible'],
#  ['young', 'current', 'various', 'capital'],
#  ...]

# %%
adj =[]
for i in documents_adj :
    adj += i
adj
# Out:
# ['wealthy',
#  'poorer',
#  'past',
#  'annual',
#  'first',
#  'older',
#  'past',
#  'special',
#  'televised',
#  'first',
#  'tempting',
#  'nearby',
#  'poisonous',
#  'dead',
#  'infected',
#  'poisonous',
#  'prolonged',
#  'victorious',
#  'powerful',
#  'prison',
#  'earlier',
#  'top',
#  'civil',
#  'former',
#  'dead',
#  'gross',
#  'promising',
#  'funeral',
#  'first',
#  'good',
#  'dead',
#  'whole',
#  'close',
#  'supreme',
#  'hidden',
#  'funeral',
#  'last',
#  'ritual',
#  'peaceful',
#  'touting',
#  'several',
#  'gullible',
#  'prefabricated',
#  'notorious',
#  'dead',
#  'last',
#  'first',
#  'local',
#  'previous',
#  'underhanded',
#  'short',
#  'legitimate',
#  'key',
#  'jailed',
#  'small',
#  'elderly',
#  'free',
#  'unaware',
#  'overjoyed',
#  'wherever',
#  'late',
#  'oversized',
#  'true',
#  'angry',
#  'elderly',
#  'secure',
#  'original',
#  'little',
#  'old',
#  'earlier',
#  'necessary',
#  'main',
#  'free',
#  'certain',
#  'animal',
#  'subsequent',
#  'true',
#  'public',
#  'stoic',
#  'religious',
#  'new',
#  'circumstantial',
#  'small',
#  'wooden',
#  'seven',
#  'guilty',
#  'guilty',
#  'guilty',
#  'suspended',
#  'english',
#  'small',
#  'secret',
#  'main',
#  'secret',
#  'investigative',
#  'third',
#  'suspicious',
#  'previous',
#  'dead',
#  'first',
#  'first',
#  'unfaithful',
#  'young',
#  'outside',
#  'bitter',
#  'closer',
#  'good',
#  'full',
#  'great',
#  'unstable',
#  'new',
#  'dilapidated',
#  'large',
#  'dark',
#  'dark',
#  'former',
#  'former',
#  'little',
#  'new',
#  'much',
#  'laundry',
#  'dark',
#  'kyle',
#  'strange',
#  'aware',
#  'closer',
#  'weird',
#  'young',
#  'senior',
#  'high',
#  'small',
#  'alive',
#  'sing',
#  'young',
#  'first',
#  'uninterested',
#  'sing',
#  'traditional',
#  'dominic',
#  'local',
#  'first',
#  'hesitant',
#  'ex',
#  'dominic',
#  'uniting',
#  'enough',
#  'upcoming',
#  'informed',
#  'recent',
#  'great',
#  'senior',
#  'main',
#  'unconscious',
#  'dominic',
#  'fictional',
#  'fictional',
#  'fake',
#  'equal',
#  'original',
#  'former',
#  'injured',
#  'new',
#  'plush',
#  'extended',
#  'whole',
#  'brought',
#  'local',
#  'grassroots',
#  'simple',
#  'altruistic',
#  'new',
#  'first',
#  'nationwide',
#  'prepared',
#  'original',
#  'historical',
#  'short',
#  'usual',
#  'invisible',
#  'invisible',
#  'best',
#  'secret',
#  'married',
#  'antique',
#  'mean',
#  'secret',
#  'angry',
#  'previous',
#  'selfish',
#  'happy',
#  'illegal',
#  'responsible',
#  'illegal',
#  'barren',
#  'inoperable',
#  'complicated',
#  'onetime',
#  'american',
#  'british',
#  'jewish',
#  'british',
#  'second',
#  'jewish',
#  'illegal',
#  'military',
#  'british',
#  'british',
#  'safe',
#  'young',
#  'young',
#  'new',
#  'young',
#  'radical',
#  'mainstream',
#  'jewish',
#  'diplomatic',
#  'british',
#  'ill',
#  'fictional',
#  'jewish',
#  'actual',
#  'present',
#  'lebanese',
#  'historical',
#  'british',
#  'lifelong',
#  'independent',
#  'prior',
#  'younger',
#  'overnight',
#  'ecstatic',
#  'new',
#  'following',
#  'jewish',
#  'local',
#  'willing',
#  'new',
#  'white',
#  'strong',
#  'minded',
#  'strong',
#  'beautiful',
#  'older',
#  'safe',
#  'main',
#  'small',
#  'denied',
#  'several',
#  'ends',
#  'worse',
#  'new',
#  'angry',
#  'possible',
#  'personal',
#  'ta',
#  'free',
#  'close',
#  'enough',
#  'full',
#  'hot',
#  'chase',
#  'whole',
#  'reluctant',
#  'old',
#  'first',
#  'sexual',
#  'remote',
#  'evil',
#  'biggest',
#  'valuable',
#  'longstanding',
#  'favorite',
#  'favorite',
#  'little',
#  'high',
#  'high',
#  'popular',
#  'true',
#  'surreal',
#  'young',
#  'wealthy',
#  'whole',
#  'early',
#  'opening',
#  'latest',
#  'italian',
#  'financial',
#  'best',
#  'secret',
#  'sexual',
#  'exclusive',
#  'beautiful',
#  'similar',
#  'former',
#  'possessive',
#  'italian',
#  'dead',
#  'main',
#  'sadistic',
#  'younger',
#  'financial',
#  'ensuing',
#  'fictional',
#  'young',
#  'unfamiliar',
#  'silent',
#  'general',
#  'former',
#  'unhappily',
#  'married',
#  'second',
#  'early',
#  'italian',
#  'comic',
#  'several',
#  'subsequent',
#  'lonely',
#  'red',
#  'clown',
#  'scattered',
#  'underneath',
#  'confused',
#  'second',
#  'green',
#  'red',
#  'uproarous',
#  'short',
#  'sexual',
#  'several',
#  'opposite',
#  'composite',
#  'slave',
#  'existed',
#  'petty',
#  'white',
#  'dead',
#  'sexual',
#  'overwhelming',
#  'social',
#  'successive',
#  'black',
#  'native',
#  'treacherous',
#  'unwritten',
#  'black',
#  'white',
#  'contradictory',
#  'severe',
#  'defenseless',
#  'capricious',
#  'white',
#  'black',
#  'best',
#  'minor',
#  'responsible',
#  'best',
#  'new',
#  'big',
#  'honourable',
#  'young',
#  'orphaned',
#  'former',
#  'evil',
#  'orphaned',
#  'innocent',
#  'young',
#  'personal',
#  'former',
#  'safe',
#  'happy',
#  'whole',
#  'good',
#  'naïve',
#  'young',
#  'new',
#  'big',
#  'gang',
#  'simple',
#  'protective',
#  'good',
#  'young',
#  'beautiful',
#  'young',
#  'young',
#  'wounded',
#  'initial',
#  'new',
#  'undercover',
#  'real',
#  'secret',
#  'bliss',
#  'learn',
#  'aware',
#  'public',
#  'young',
#  'possible',
#  'ecstatic',
#  'evil',
#  'whole',
#  'late',
#  'local',
#  'true',
#  'little',
#  'entire',
#  'whole',
#  'real',
#  'little',
#  'earliest',
#  'little',
#  'upcoming',
#  'interested',
#  'big',
#  'last',
#  'young',
#  'little',
#  'failing',
#  'unable',
#  'legs',
#  'lest',
#  'ritual',
#  'essential',
#  'last',
#  'overwhelms',
#  'poor',
#  'last',
#  'horrible',
#  'last',
#  'hidden',
#  'red',
#  'injured',
#  'identical',
#  'single',
#  'trouble',
#  'local',
#  'unmarried',
#  'unsuspecting',
#  'married',
#  'egotistical',
#  'enough',
#  'proud',
#  'lovely',
#  'overprotective',
#  'professional',
#  'favorite',
#  'westernized',
#  'suspicious',
#  'traditional',
#  'traditional',
#  'indian',
#  'false',
#  'known',
#  'heavy',
#  'high',
#  'general',
#  'deep',
#  'public',
#  'main',
#  'alive',
#  'rubble',
#  'closest',
#  'lonely',
#  'poor',
#  'poor',
#  'good',
#  'stolen',
#  'social',
#  'worst',
#  'crowded',
#  'high',
#  'frantic',
#  'unsuccessful',
#  'sustained',
#  'nervous',
#  'unable',
#  'high',
#  'unstable',
#  'high',
#  'attempted',
#  'painful',
#  'best',
#  'safe',
#  'real',
#  'first',
#  'old',
#  'arrive',
#  'front',
#  'bloody',
#  'nanny',
#  'black',
#  'red',
#  'giant',
#  'giant',
#  'psychopathic',
#  'real',
#  'psychotic',
#  'first',
#  'fourth',
#  'last',
#  'upper',
#  'alive',
#  'tent',
#  'virtual',
#  'flimsy',
#  'hostile',
#  'unable',
#  'difficult',
#  'worst',
#  'confront',
#  'general',
#  'local',
#  'main',
#  'friendship',
#  'bitter',
#  'idle',
#  'continuous',
#  'adult',
#  'impoverished',
#  'high',
#  'unceasing',
#  'communal',
#  'main',
#  'ideal',
#  'renowned',
#  'mismanaged',
#  'psychological',
#  'elaborate',
#  'fake',
#  'last',
#  'much',
#  'funeral',
#  'dead',
#  'complete',
#  'various',
#  'usual',
#  'frenetic',
#  'various',
#  'small',
#  'strong',
#  'high',
#  'young',
#  'various',
#  'social',
#  'enigmatic',
#  'young',
#  'dramatic',
#  'big',
#  'real',
#  'factual',
#  'worldly',
#  'historical',
#  'southern',
#  'reluctant',
#  'sworn',
#  'entrapped',
#  'infant',
#  'diplomatic',
#  'subsequent',
#  'advancing',
#  'light',
#  'main',
#  'main',
#  'miniaturised',
#  'allied',
#  'unsuspecting',
#  'disheartened',
#  'new',
#  'red',
#  'right',
#  'military',
#  'ingenious',
#  'respective',
#  'earlier',
#  'folly',
#  'late',
#  'special',
#  'climatic',
#  'southeast',
#  'ambitious',
#  'entire',
#  'offensive',
#  'testudo',
#  'heavy',
#  'main',
#  'western',
#  'title',
#  'opening',
#  'historical',
#  'asian',
#  'notable',
#  'early',
#  'western',
#  'original',
#  'japanese',
#  'thief',
#  'japanese',
#  'manchurian',
#  'various',
#  'good',
#  'third',
#  'manchurian',
#  'escalating',
#  'japanese',
#  'japanese',
#  'graphic',
#  'manchurian',
#  'japanese',
#  'good',
#  'japanese',
#  'good',
#  'prolonged',
#  'useless',
#  'crude',
#  'good',
#  'new',
#  'old',
#  'russian',
#  'ukrainian',
#  'former',
#  'urges',
#  'unstable',
#  'former',
#  'impressed',
#  'full',
#  'appropriate',
#  'incompetent',
#  'severe',
#  'british',
#  'senior',
#  'undercover',
#  'statutory',
#  'safe',
#  'unable',
#  'little',
#  'last',
#  'sign',
#  'animal',
#  'old',
#  'beautiful',
#  'strange',
#  'difficult',
#  'future',
#  'unexpected',
#  'funny',
#  'opposite',
#  'trusting',
#  'several',
#  'numerous',
#  'various',
#  'older',
#  'financial',
#  'local',
#  'unpaid',
#  'various',
#  'old',
#  'old',
#  'sufficient',
#  'right',
#  'terrorist',
#  'opposite',
#  'christian',
#  'sentimental',
#  'young',
#  'impending',
#  'senior',
#  'foppish',
#  'british',
#  'receptive',
#  'evil',
#  'young',
#  'good',
#  'respective',
#  'skilled',
#  'destroy',
#  'unhappy',
#  'helpful',
#  'evil',
#  'old',
#  'institutionalized',
#  'mental',
#  'worst',
#  'strict',
#  'single',
#  'full',
#  'owed',
#  'serial',
#  'unanimous',
#  'dead',
#  'public',
#  'detective',
#  'wealthy',
#  'old',
#  'nymphomaniac',
#  'amnesiac',
#  'fortune',
#  'least',
#  'oral',
#  'drunken',
#  'present',
#  'young',
#  'prosthetic',
#  'tragic',
#  'allergic',
#  'various',
#  'melodramatic',
#  'cello',
#  'first',
#  'tragic',
#  'dead',
#  'plaintive',
#  'jagged',
#  'enough',
#  'legs',
#  'tragic',
#  'giant',
#  'shattered',
#  'spilled',
#  'entire',
#  'slum',
#  'similar',
#  'present',
#  'poor',
#  'beautiful',
#  'young',
#  'unforgiving',
#  'young',
#  'young',
#  'films',
#  'former',
#  'socialite',
#  'couple',
#  'pen',
#  'unhappy',
#  'german',
#  'british',
#  'american',
#  'maximum',
#  'rendezvous',
#  'new',
#  'german',
#  'valuable',
#  'supposedly',
#  'unbreakable',
#  'dead',
#  'funeral',
#  'free',
#  'russian',
#  'german',
#  'new',
#  'american',
#  'new',
#  'rendezvous',
#  'unexplainable',
#  'phenomena',
#  'mysterious',
#  'first',
#  'mysterious',
#  'whole',
#  'short',
#  'utilizes',
#  'otherworldly',
#  'wide',
#  'small',
#  'beautiful',
#  'black',
#  'abandoned',
#  'shot',
#  'nice',
#  'outside',
#  'abandoned',
#  'real',
#  'young',
#  'outside',
#  'abandoned',
#  'trio',
#  'english',
#  'free',
#  'entire',
#  'jamal',
#  'oral',
#  'good',
#  'evil',
#  'palpable',
#  'old',
#  'tiny',
#  'unmoored',
#  'strong',
#  'first',
#  'long',
#  'good',
#  'right',
#  'best',
#  'metaphysical',
#  'angry',
#  'long',
#  'long',
#  'alive',
#  'best',
#  'divorced',
#  'right',
#  'dead',
#  'new',
#  'unhappy',
#  'respective',
#  'everyday',
#  'intimate',
#  'unassuming',
#  'love',
#  'married',
#  'dead',
#  'late',
#  'usual',
#  'sheepishly',
#  'inexorable',
#  'opposite',
#  'best',
#  'narrow',
#  'opposite',
#  'first',
#  'empty',
#  'safe',
#  'chest',
#  'safe',
#  'fourth',
#  'safe',
#  'second',
#  'fifth',
#  'dazed',
#  'unhurt',
#  'third',
#  'unable',
#  'sixth',
#  'actual',
#  'unhappy',
#  'yellow',
#  'new',
#  'explosive',
#  'first',
#  'little',
#  'agitated',
#  'original',
#  'cheap',
#  'whole',
#  'full',
#  'normal',
#  'small',
#  'ecstatic',
#  'tall',
#  'amplified',
#  'previous',
#  'great',
#  'white',
#  'older',
#  'carefree',
#  'marine',
#  'strange',
#  'unexplained',
#  'tracking',
#  'unharmed',
#  'inflatable',
#  'explosive',
#  'electrical',
#  'absent',
#  'broken',
#  'injured',
#  'alive',
#  'big',
#  'unable',
#  'best',
#  'best',
#  'powerful',
#  'considerable',
#  'favourite',
#  'current',
#  'repeated',
#  'responsible',
#  'dead',
#  'uplifting',
#  'warm',
#  'crippling',
#  'great',
#  'paraplegic',
#  'little',
#  'rich',
#  'good',
#  'original',
#  'warm',
#  'true',
#  'personal',
#  'insecure',
#  'best',
#  'older',
#  'several',
#  'authorized',
#  'private',
#  'temporary',
#  'military',
#  'older',
#  'impressed',
#  'israeli',
#  'high',
#  'steady',
#  'great',
#  'main',
#  'carefree',
#  'positive',
#  'heavy',
#  'rapid',
#  'swab',
#  'positive',
#  'young',
#  'secret',
#  'high',
#  'mexican',
#  'high',
#  'third',
#  'black',
#  'dark',
#  'major',
#  'bloody',
#  'glowing',
#  'demon',
#  'first',
#  'second',
#  'unable',
#  'magical',
#  'magical',
#  'black',
#  'speak',
#  'french',
#  'personal',
#  'various',
#  'actuary',
#  'new',
#  'foster',
#  'small',
#  'tanzanian',
#  'candid',
#  'young',
#  'declined',
#  'entire',
#  'longtime',
#  'arrive',
#  'funeral',
#  'cheap',
#  'waterbed',
#  'hidden',
#  'mutual',
#  'new',
#  'clear',
#  'right',
#  'late',
#  'full',
#  'hot',
#  'dead',
#  'illiterate',
#  'financial',
#  'large',
#  'small',
#  'sunny',
#  'difficult',
#  'nervous',
#  'young',
#  'ambitious',
#  'idealistic',
#  'remote',
#  'rural',
#  'secure',
#  'unwilling',
#  'backward',
#  'first',
#  'acquainted',
#  'long',
#  'old',
#  'new',
#  'isolated',
#  'reluctant',
#  'first',
#  'agonized',
#  'dead',
#  'temporary',
#  'large',
#  'good',
#  'contemptuous',
#  'prolonged',
#  'best',
#  'safe',
#  'chinese',
#  'good',
#  'shot',
#  'new',
#  'new',
#  'old',
#  'menial',
#  'biggest',
#  'relative',
#  'worse',
#  'worse',
#  'small',
#  'following',
#  'dried',
#  ...]

# %%
documents_adj = adj

# %%
vocabulary=list(set(documents_adj))
word_counts = {word: documents_adj.count(word) for word in vocabulary}
word_count_df = pd.DataFrame(list(word_counts.items()), columns=['Word', 'Count'])
# only use the words appear at least twice
documents_adj=list(word_count_df[word_count_df['Count']>1]['Word'])

# %%
word_count_df.sort_values(by="Count", ascending = False).head(20)

# %%
sns.histplot(data = word_count_df, x ="Word", y = "Count")

# %%
# remove some words in case of incorrect classification
lines = []

# file from https://www.cs.cmu.edu/afs/cs/project/ai-repository/ai/areas/nlp/corpora/names/
with open('data/female name.txt', 'r', encoding='utf-8') as file:
    for line in file:
        line=line.lower()
        lines.append(line.strip())
documents_adj = set(documents_adj)-set(lines)

lines = []
with open('data/male name.txt', 'r', encoding='utf-8') as file:
    for line in file:
        line=line.lower()
        lines.append(line.strip())
documents_adj = set(documents_adj)-set(lines)


print(len(documents_adj))
other_common_words = set(['child', 'orphan', 'baby', 'girls', 'lover', 'mute','child', 'orphan', 'bride', 
                          'baby', 'girls', 'lover', 'mute', 'housekeeper', 'cousin', 'neighbour', 'parent', 
                          'sibling', 'pregnant', 'housewife', 'relative', 'servant', 'waif', 'grandson', 
                          'stranger', 'courtesan', 'servant','cousin', 'neighbour', 'parent', 'sibling', 
                          'housewife','nurse', 'stepsister', 'housekeeper','grandson','servant','grandchildren',
                          'relatives', 'uncles', 'orphans', 'childbirth', 'scoundrel', 'foreigner', 'stepfamily', 
                          'tuberculosis', 'mallaya', 'triplet', 'grandchildren', 'outcast', 'neighbours', 'huanhuan', 
                          'lakshmiammal', 'jaipal', 'himal', 'pasarian', 'leukemia'])
documents_adj = set(documents_adj)-set(other_common_words)
# Out:
# 42306
